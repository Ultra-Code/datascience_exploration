# %% [markdown]
# # Aggregation using window functions
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# - Understand the concept of window functions in SQL.
# - Learn how to use window functions for data aggregation.
# - Understand how to use window functions to partition data.
# - Practise using window functions to solve complex problems.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore how to use window functions in SQL to solve complex problems. Window functions are a type of function in SQL that performs a calculation across a set of table rows that are related to the current row.
#
# We will use the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, and access to basic services.
#
# Let's begin by calculating each country's land cover as a percentage per subregion for the year 2020.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name.

# %sql mysql+pymysql://ultracode:ultracode@localhost:3306/united_nations

# %% [markdown]
# ## Exercise
#
# ### Task 1: Select the data required for the analysis
#
# The columns you select should include:
# - `Sub_region`
# - `Country_name`
# - `Land_area`
#
# Filter out the results using the following criteria:
# - For the `Time_period` of `2020`.
# - For `Land_area` values that are not missing.

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area
# From
#     Access_to_Basic_Services
# WHERE
#     Time_period=2020
# AND
#     Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://ultracode:***@localhost:3306/united_nations
# 130 rows affected.
# [('Central Asia', 'Kazakhstan', Decimal('2699700.00')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00')),
#  ('Southern Asia', 'India', Decimal('2973190.00')),
#  ('Southern Asia', 'Maldives', Decimal('300.00')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00')),
#  ('Eastern Asia', 'China', Decimal('9424702.90')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00')),
#  ('Northern America', 'Bermuda', Decimal('54.00')),
#  ('Northern America', 'Canada', Decimal('8965590.00')),
#  ('Northern America', 'Greenland', Decimal('410450.00')),
#  ('Caribbean', 'Barbados', Decimal('430.00')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00')),
#  ('Caribbean', 'Cuba', Decimal('103800.00')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00')),
#  ('Caribbean', 'Haiti', Decimal('27560.00')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00')),
#  ('Central America', 'Belize', Decimal('22810.00')),
#  ('Central America', 'Costa Rica', Decimal('51060.00')),
#  ('Central America', 'El Salvador', Decimal('20720.00')),
#  ('Central America', 'Guatemala', Decimal('107160.00')),
#  ('Central America', 'Honduras', Decimal('111890.00')),
#  ('Central America', 'Mexico', Decimal('1943950.00')),
#  ('Central America', 'Nicaragua', Decimal('120340.00')),
#  ('Central America', 'Panama', Decimal('74180.00')),
#  ('South America', 'Argentina', Decimal('2736690.00')),
#  ('South America', 'Brazil', Decimal('8358140.00')),
#  ('South America', 'Chile', Decimal('743532.00')),
#  ('South America', 'Colombia', Decimal('1109500.00')),
#  ('South America', 'Ecuador', Decimal('248360.00')),
#  ('South America', 'Guyana', Decimal('196850.00')),
#  ('South America', 'Paraguay', Decimal('397300.00')),
#  ('South America', 'Peru', Decimal('1280000.00')),
#  ('South America', 'Suriname', Decimal('156000.00')),
#  ('South America', 'Uruguay', Decimal('175020.00')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00')),
#  ('Western Asia', 'Armenia', Decimal('28470.00')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00')),
#  ('Western Asia', 'Bahrain', Decimal('785.00')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00')),
#  ('Western Asia', 'Georgia', Decimal('69490.00')),
#  ('Western Asia', 'Iraq', Decimal('434128.00')),
#  ('Western Asia', 'Israel', Decimal('21640.00')),
#  ('Western Asia', 'Jordan', Decimal('88794.00')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00')),
#  ('Western Asia', 'Oman', Decimal('309500.00')),
#  ('Western Asia', 'Qatar', Decimal('11490.00')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00')),
#  ('Australia and New Zealand', 'Australia', Decimal('7692020.00')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00')),
#  ('Melanesia', 'Fiji', Decimal('18270.00')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00')),
#  ('Micronesia', 'Guam', Decimal('540.00')),
#  ('Micronesia', 'Kiribati', Decimal('810.00')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00')),
#  ('Micronesia', 'Nauru', Decimal('20.00')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00')),
#  ('Micronesia', 'Palau', Decimal('460.00')),
#  ('Polynesia', 'American Samoa', Decimal('200.00')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00')),
#  ('Polynesia', 'Samoa', Decimal('2780.00')),
#  ('Polynesia', 'Tonga', Decimal('720.00')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00')),
#  ('Western Africa', 'Benin', Decimal('112760.00')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00')),
#  ('Western Africa', 'Ghana', Decimal('227533.00')),
#  ('Western Africa', 'Guinea', Decimal('245720.00')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00')),
#  ('Western Africa', 'Liberia', Decimal('96320.00')),
#  ('Western Africa', 'Mali', Decimal('1220190.00')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00')),
#  ('Western Africa', 'Niger', Decimal('1266700.00')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00')),
#  ('Western Africa', 'Senegal', Decimal('192530.00')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00')),
#  ('Western Africa', 'Togo', Decimal('54390.00'))]

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion
#
#
# Calculate each land area as a percentage within its sub_region:
# - Divide the `Land_area` by the `SUM()` `BY` the areas `OVER` each `Sub_region`'s `PARTITION`. Name this column `pct_sub_region_land_area`.
# - `Round` the calculation off to `4` decimal places.
#
# Add this line to the query from the first task.

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/SUM(Land_area) OVER(PARTITION BY
#                         Sub_region),4)*100 AS pct_sub_region_land_area
# From
#     Access_to_Basic_Services
# WHERE
#     Time_period=2020
# AND
#     Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://ultracode:***@localhost:3306/united_nations
# 130 rows affected.
# [('Australia and New Zealand', 'Australia', Decimal('7692020.00'), Decimal('96.6900')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00'), Decimal('3.3100')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00'), Decimal('4.3300')),
#  ('Caribbean', 'Barbados', Decimal('430.00'), Decimal('0.2100')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00'), Decimal('2.5000')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00'), Decimal('0.0700')),
#  ('Caribbean', 'Cuba', Decimal('103800.00'), Decimal('50.6100')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00'), Decimal('23.5600')),
#  ('Caribbean', 'Haiti', Decimal('27560.00'), Decimal('13.4400')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00'), Decimal('5.2800')),
#  ('Central America', 'Mexico', Decimal('1943950.00'), Decimal('79.2800')),
#  ('Central America', 'Nicaragua', Decimal('120340.00'), Decimal('4.9100')),
#  ('Central America', 'Belize', Decimal('22810.00'), Decimal('0.9300')),
#  ('Central America', 'Panama', Decimal('74180.00'), Decimal('3.0300')),
#  ('Central America', 'Costa Rica', Decimal('51060.00'), Decimal('2.0800')),
#  ('Central America', 'El Salvador', Decimal('20720.00'), Decimal('0.8400')),
#  ('Central America', 'Guatemala', Decimal('107160.00'), Decimal('4.3700')),
#  ('Central America', 'Honduras', Decimal('111890.00'), Decimal('4.5600')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00'), Decimal('3.7000')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00'), Decimal('12.5300')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00'), Decimal('11.7500')),
#  ('Central Asia', 'Kazakhstan', Decimal('2699700.00'), Decimal('72.0100')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00'), Decimal('0.0300')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00'), Decimal('0.4400')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00'), Decimal('6.6400')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00'), Decimal('13.5000')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00'), Decimal('0.4000')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00'), Decimal('0.4200')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26'), Decimal('19.3700')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00'), Decimal('10.7700')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00'), Decimal('9.7700')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00'), Decimal('10.8500')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00'), Decimal('9.9900')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00'), Decimal('3.4400')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00'), Decimal('1.6200')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00'), Decimal('12.7600')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80'), Decimal('13.7300')),
#  ('Eastern Asia', 'China', Decimal('9424702.90'), Decimal('83.0600')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00'), Decimal('3.2100')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00'), Decimal('5.2900')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00'), Decimal('2.3000')),
#  ('Melanesia', 'Fiji', Decimal('18270.00'), Decimal('3.4500')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00'), Decimal('3.4500')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00'), Decimal('85.5100')),
#  ('Micronesia', 'Palau', Decimal('460.00'), Decimal('18.6200')),
#  ('Micronesia', 'Guam', Decimal('540.00'), Decimal('21.8600')),
#  ('Micronesia', 'Kiribati', Decimal('810.00'), Decimal('32.7900')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00'), Decimal('7.2900')),
#  ('Micronesia', 'Nauru', Decimal('20.00'), Decimal('0.8100')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00'), Decimal('18.6200')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00'), Decimal('0.0200')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00'), Decimal('32.3000')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00'), Decimal('12.2500')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00'), Decimal('16.1400')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00'), Decimal('32.6200')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00'), Decimal('6.6800')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00'), Decimal('36.0300')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00'), Decimal('26.6200')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00'), Decimal('6.7500')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00'), Decimal('28.2600')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00'), Decimal('2.3500')),
#  ('Northern America', 'Bermuda', Decimal('54.00'), Decimal('0.0000')),
#  ('Northern America', 'Canada', Decimal('8965590.00'), Decimal('95.6200')),
#  ('Northern America', 'Greenland', Decimal('410450.00'), Decimal('4.3800')),
#  ('Polynesia', 'American Samoa', Decimal('200.00'), Decimal('2.7800')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00'), Decimal('48.2000')),
#  ('Polynesia', 'Samoa', Decimal('2780.00'), Decimal('38.6100')),
#  ('Polynesia', 'Tonga', Decimal('720.00'), Decimal('10.0000')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00'), Decimal('0.4200')),
#  ('South America', 'Colombia', Decimal('1109500.00'), Decimal('7.2000')),
#  ('South America', 'Ecuador', Decimal('248360.00'), Decimal('1.6100')),
#  ('South America', 'Guyana', Decimal('196850.00'), Decimal('1.2800')),
#  ('South America', 'Paraguay', Decimal('397300.00'), Decimal('2.5800')),
#  ('South America', 'Argentina', Decimal('2736690.00'), Decimal('17.7700')),
#  ('South America', 'Peru', Decimal('1280000.00'), Decimal('8.3100')),
#  ('South America', 'Brazil', Decimal('8358140.00'), Decimal('54.2700')),
#  ('South America', 'Suriname', Decimal('156000.00'), Decimal('1.0100')),
#  ('South America', 'Chile', Decimal('743532.00'), Decimal('4.8300')),
#  ('South America', 'Uruguay', Decimal('175020.00'), Decimal('1.1400')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00'), Decimal('0.0200')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00'), Decimal('0.1400')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00'), Decimal('13.2200')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00'), Decimal('4.5700')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00'), Decimal('0.3800')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00'), Decimal('48.5800')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00'), Decimal('8.5000')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00'), Decimal('16.8900')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00'), Decimal('7.7100')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00'), Decimal('21.3800')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00'), Decimal('0.6500')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00'), Decimal('1.1500')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00'), Decimal('31.0600')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00'), Decimal('45.7700')),
#  ('Southern Asia', 'Maldives', Decimal('300.00'), Decimal('0.0100')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00'), Decimal('3.0100')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00'), Decimal('16.1600')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00'), Decimal('13.6700')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00'), Decimal('1.3000')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00'), Decimal('2.7300')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00'), Decimal('0.8000')),
#  ('Southern Asia', 'India', Decimal('2973190.00'), Decimal('62.3300')),
#  ('Western Africa', 'Togo', Decimal('54390.00'), Decimal('0.9500')),
#  ('Western Africa', 'Mali', Decimal('1220190.00'), Decimal('21.2700')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00'), Decimal('4.7700')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00'), Decimal('17.9700')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00'), Decimal('0.0700')),
#  ('Western Africa', 'Niger', Decimal('1266700.00'), Decimal('22.0900')),
#  ('Western Africa', 'Ghana', Decimal('227533.00'), Decimal('3.9700')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00'), Decimal('15.8800')),
#  ('Western Africa', 'Guinea', Decimal('245720.00'), Decimal('4.2800')),
#  ('Western Africa', 'Senegal', Decimal('192530.00'), Decimal('3.3600')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00'), Decimal('0.4900')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00'), Decimal('1.2600')),
#  ('Western Africa', 'Liberia', Decimal('96320.00'), Decimal('1.6800')),
#  ('Western Africa', 'Benin', Decimal('112760.00'), Decimal('1.9700')),
#  ('Western Asia', 'Jordan', Decimal('88794.00'), Decimal('2.5500')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00'), Decimal('2.3700')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00'), Decimal('2.0400')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00'), Decimal('0.5100')),
#  ('Western Asia', 'Bahrain', Decimal('785.00'), Decimal('0.0200')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00'), Decimal('0.2900')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00'), Decimal('0.2600')),
#  ('Western Asia', 'Oman', Decimal('309500.00'), Decimal('8.8700')),
#  ('Western Asia', 'Georgia', Decimal('69490.00'), Decimal('1.9900')),
#  ('Western Asia', 'Qatar', Decimal('11490.00'), Decimal('0.3300')),
#  ('Western Asia', 'Iraq', Decimal('434128.00'), Decimal('12.4400')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00'), Decimal('61.6200')),
#  ('Western Asia', 'Israel', Decimal('21640.00'), Decimal('0.6200')),
#  ('Western Asia', 'Armenia', Decimal('28470.00'), Decimal('0.8200')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00'), Decimal('5.2600'))]

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion
#
# Start by selecting the columns needed for this analysis:
# - `Sub_region`
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_gdp_in_billions`
# - `Est_population_in_millions`
#
# Calculate the running average:
# - Calculate the `AVG()` of the `Est_population_in_millions`.
# - `PARTITION` the calculation `OVER` each country's `Sub_region`, and name this column `Running_average_population`.
# - `ROUND` the calculation off to `4` decimal places.
# - Filter the results `WHERE` there are values of `Est_gdp_in_billions` that are `NOT NULL`.

# %%
# %%sql
# SELECT
#     Country_name,
#     Sub_region,
#     Time_period,
#     Pct_managed_drinking_water_services as "% drinking water service",
#     Pct_managed_sanitation_services as "% sanitation service",
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     ROUND(AVG(Est_population_in_millions) OVER(PARTITION BY
#                                                             Sub_region
#                                                ORDER BY
#                                                         Time_period),4) AS Running_average_population
# From
#     Access_to_Basic_Services
# WHERE
#     Est_gdp_in_billions IS NOT NULL
# LIMIT 10;
# Out:
#  * mysql+pymysql://ultracode:***@localhost:3306/united_nations
# 10 rows affected.
# [('New Zealand', 'Australia and New Zealand', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('178.06'), Decimal('4.609400'), Decimal('14.2127')),
#  ('Australia', 'Australia and New Zealand', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('1350.62'), Decimal('23.815995'), Decimal('14.2127')),
#  ('New Zealand', 'Australia and New Zealand', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('188.84'), Decimal('4.714100'), Decimal('14.3326')),
#  ('Australia', 'Australia and New Zealand', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('1206.54'), Decimal('24.190907'), Decimal('14.3326')),
#  ('New Zealand', 'Australia and New Zealand', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('206.62'), Decimal('4.813600'), Decimal('14.4564')),
#  ('Australia', 'Australia and New Zealand', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('1326.52'), Decimal('24.594202'), Decimal('14.4564')),
#  ('New Zealand', 'Australia and New Zealand', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('211.95'), Decimal('4.900600'), Decimal('14.5757')),
#  ('Australia', 'Australia and New Zealand', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('1428.29'), Decimal('24.966643'), Decimal('14.5757')),
#  ('New Zealand', 'Australia and New Zealand', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('213.43'), Decimal('4.979200'), Decimal('14.6925')),
#  ('Australia', 'Australia and New Zealand', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('1392.23'), Decimal('25.340217'), Decimal('14.6925'))]

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+pymysql://ultracode:***@localhost:3306/united_nations
# 4 rows affected.
# [('Access_to_Basic_Services',),
#  ('Country_list',),
#  ('contry_list_view',),
#  ('country_list',)]

# %% [markdown]
# ## Solutions
#
# ### Task 1: Select the data required for the analysis

# %%
# %%sql
# SELECT
# 	Sub_region,
#     Country_name,
#     Land_area
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area
# FROM united_nations.access_to_basic_services
#     WHERE time_period = 2020
#     AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     ROUND(AVG(Est_population_in_millions) OVER (PARTITION BY Sub_region ORDER BY Time_period),4) AS Running_average_population
# FROM Access_to_Basic_Services
#     WHERE Est_gdp_in_billions IS NOT NULL;
# Out:
#  * mysql+pymysql://ultracode:***@localhost:3306/united_nations
# 800 rows affected.
# [('Australia and New Zealand', 'New Zealand', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('178.06'), Decimal('4.609400'), Decimal('14.2127')),
#  ('Australia and New Zealand', 'Australia', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('1350.62'), Decimal('23.815995'), Decimal('14.2127')),
#  ('Australia and New Zealand', 'New Zealand', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('188.84'), Decimal('4.714100'), Decimal('14.3326')),
#  ('Australia and New Zealand', 'Australia', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('1206.54'), Decimal('24.190907'), Decimal('14.3326')),
#  ('Australia and New Zealand', 'New Zealand', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('206.62'), Decimal('4.813600'), Decimal('14.4564')),
#  ('Australia and New Zealand', 'Australia', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('1326.52'), Decimal('24.594202'), Decimal('14.4564')),
#  ('Australia and New Zealand', 'New Zealand', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('211.95'), Decimal('4.900600'), Decimal('14.5757')),
#  ('Australia and New Zealand', 'Australia', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('1428.29'), Decimal('24.966643'), Decimal('14.5757')),
#  ('Australia and New Zealand', 'New Zealand', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('213.43'), Decimal('4.979200'), Decimal('14.6925')),
#  ('Australia and New Zealand', 'Australia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('1392.23'), Decimal('25.340217'), Decimal('14.6925')),
#  ('Australia and New Zealand', 'New Zealand', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('211.73'), Decimal('5.090200'), Decimal('14.8059')),
#  ('Australia and New Zealand', 'Australia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('1326.90'), Decimal('25.655289'), Decimal('14.8059')),
#  ('Caribbean', 'Grenada', 2015, Decimal('96.00'), Decimal('91.00'), Decimal('1.00'), Decimal('0.118980'), Decimal('2.9168')),
#  ('Caribbean', 'Dominican Republic', 2015, Decimal('94.33'), Decimal('82.33'), Decimal('71.16'), Decimal('10.405832'), Decimal('2.9168')),
#  ('Caribbean', 'Aruba', 2015, Decimal('98.00'), Decimal('98.00'), Decimal('2.96'), Decimal('0.104257'), Decimal('2.9168')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2015, Decimal('95.00'), Decimal('99.00'), Decimal('1.25'), Decimal('0.038825'), Decimal('2.9168')),
#  ('Caribbean', 'Cayman Islands', 2015, Decimal('96.00'), Decimal('84.00'), Decimal('4.71'), Decimal('0.060911'), Decimal('2.9168')),
#  ('Caribbean', 'Puerto Rico', 2015, Decimal('99.00'), Decimal('100.00'), Decimal('103.38'), Decimal('3.473232'), Decimal('2.9168')),
#  ('Caribbean', 'Barbados', 2015, Decimal('98.00'), Decimal('96.00'), Decimal('4.72'), Decimal('0.278083'), Decimal('2.9168')),
#  ('Caribbean', 'Jamaica', 2015, Decimal('90.00'), Decimal('86.00'), Decimal('14.19'), Decimal('2.794445'), Decimal('2.9168')),
#  ('Caribbean', 'Haiti', 2015, Decimal('64.00'), Decimal('32.33'), Decimal('14.83'), Decimal('10.563757'), Decimal('2.9168')),
#  ('Caribbean', 'Dominica', 2015, Decimal('95.00'), Decimal('80.00'), Decimal('0.54'), Decimal('0.070007'), Decimal('2.9168')),
#  ('Caribbean', 'Antigua and Barbuda', 2015, Decimal('97.00'), Decimal('88.00'), Decimal('1.34'), Decimal('0.089941'), Decimal('2.9168')),
#  ('Caribbean', 'Cuba', 2015, Decimal('94.67'), Decimal('88.67'), Decimal('87.13'), Decimal('11.339894'), Decimal('2.9168')),
#  ('Caribbean', 'Turks and Caicos Islands', 2015, Decimal('94.00'), Decimal('88.00'), Decimal('0.94'), Decimal('0.036538'), Decimal('2.9168')),
#  ('Caribbean', 'Trinidad and Tobago', 2015, Decimal('98.00'), Decimal('94.00'), Decimal('26.85'), Decimal('1.460177'), Decimal('2.9168')),
#  ('Caribbean', 'Trinidad and Tobago', 2016, Decimal('99.00'), Decimal('94.00'), Decimal('23.50'), Decimal('1.469330'), Decimal('2.9251')),
#  ('Caribbean', 'Grenada', 2016, Decimal('96.00'), Decimal('91.00'), Decimal('1.06'), Decimal('0.119966'), Decimal('2.9251')),
#  ('Caribbean', 'Dominican Republic', 2016, Decimal('94.67'), Decimal('83.00'), Decimal('75.70'), Decimal('10.527592'), Decimal('2.9251')),
#  ('Caribbean', 'Aruba', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('2.98'), Decimal('0.104874'), Decimal('2.9251')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2016, Decimal('95.00'), Decimal('99.00'), Decimal('1.26'), Decimal('0.039969'), Decimal('2.9251')),
#  ('Caribbean', 'Cayman Islands', 2016, Decimal('96.00'), Decimal('84.00'), Decimal('4.91'), Decimal('0.062255'), Decimal('2.9251')),
#  ('Caribbean', 'Puerto Rico', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('104.34'), Decimal('3.406672'), Decimal('2.9251')),
#  ('Caribbean', 'Barbados', 2016, Decimal('98.00'), Decimal('97.00'), Decimal('4.83'), Decimal('0.278649'), Decimal('2.9251')),
#  ('Caribbean', 'Jamaica', 2016, Decimal('90.33'), Decimal('86.00'), Decimal('14.08'), Decimal('2.802695'), Decimal('2.9251')),
#  ('Caribbean', 'Haiti', 2016, Decimal('64.33'), Decimal('33.33'), Decimal('13.99'), Decimal('10.713849'), Decimal('2.9251')),
#  ('Caribbean', 'Dominica', 2016, Decimal('95.00'), Decimal('80.00'), Decimal('0.58'), Decimal('0.070075'), Decimal('2.9251')),
#  ('Caribbean', 'Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('88.00'), Decimal('1.44'), Decimal('0.090564'), Decimal('2.9251')),
#  ('Caribbean', 'Cuba', 2016, Decimal('95.00'), Decimal('89.00'), Decimal('91.37'), Decimal('11.342012'), Decimal('2.9251')),
#  ('Caribbean', 'Turks and Caicos Islands', 2016, Decimal('94.00'), Decimal('88.00'), Decimal('1.03'), Decimal('0.038246'), Decimal('2.9251')),
#  ('Caribbean', 'Dominica', 2017, Decimal('95.00'), Decimal('80.00'), Decimal('0.52'), Decimal('0.070403'), Decimal('3.0751')),
#  ('Caribbean', 'Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('88.00'), Decimal('1.47'), Decimal('0.091119'), Decimal('3.0751')),
#  ('Caribbean', 'Cuba', 2017, Decimal('95.33'), Decimal('89.33'), Decimal('96.85'), Decimal('11.336405'), Decimal('3.0751')),
#  ('Caribbean', 'Turks and Caicos Islands', 2017, Decimal('94.00'), Decimal('88.00'), Decimal('1.02'), Decimal('0.039844'), Decimal('3.0751')),
#  ('Caribbean', 'Trinidad and Tobago', 2017, Decimal('99.00'), Decimal('94.00'), Decimal('23.80'), Decimal('1.478607'), Decimal('3.0751')),
#  ('Caribbean', 'Grenada', 2017, Decimal('96.00'), Decimal('91.00'), Decimal('1.13'), Decimal('0.120921'), Decimal('3.0751')),
#  ('Caribbean', 'Dominican Republic', 2017, Decimal('94.67'), Decimal('83.33'), Decimal('80.00'), Decimal('10.647244'), Decimal('3.0751')),
#  ('Caribbean', 'Sint Maarten (Dutch part)', 2017, Decimal('95.00'), Decimal('99.00'), Decimal('1.19'), Decimal('0.040574'), Decimal('3.0751')),
#  ('Caribbean', 'Puerto Rico', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('103.45'), Decimal('3.325286'), Decimal('3.0751')),
#  ('Caribbean', 'Barbados', 2017, Decimal('98.00'), Decimal('97.00'), Decimal('4.98'), Decimal('0.279187'), Decimal('3.0751')),
#  ('Caribbean', 'Jamaica', 2017, Decimal('90.33'), Decimal('86.33'), Decimal('14.81'), Decimal('2.808376'), Decimal('3.0751')),
#  ('Caribbean', 'Haiti', 2017, Decimal('64.33'), Decimal('34.33'), Decimal('15.04'), Decimal('10.863543'), Decimal('3.0751')),
#  ('Caribbean', 'Barbados', 2018, Decimal('99.00'), Decimal('97.00'), Decimal('5.10'), Decimal('0.279688'), Decimal('3.4154')),
#  ('Caribbean', 'Jamaica', 2018, Decimal('90.33'), Decimal('86.67'), Decimal('15.73'), Decimal('2.811835'), Decimal('3.4154')),
#  ('Caribbean', 'Haiti', 2018, Decimal('64.67'), Decimal('35.33'), Decimal('16.46'), Decimal('11.012421'), Decimal('3.4154')),
#  ('Caribbean', 'Cuba', 2018, Decimal('96.00'), Decimal('89.67'), Decimal('100.05'), Decimal('11.328244'), Decimal('3.4154')),
#  ('Caribbean', 'Turks and Caicos Islands', 2018, Decimal('94.00'), Decimal('88.00'), Decimal('1.11'), Decimal('0.041487'), Decimal('3.4154')),
#  ('Caribbean', 'Trinidad and Tobago', 2018, Decimal('99.00'), Decimal('94.00'), Decimal('24.32'), Decimal('1.504709'), Decimal('3.4154')),
#  ('Caribbean', 'Dominican Republic', 2018, Decimal('95.00'), Decimal('83.67'), Decimal('85.56'), Decimal('10.765531'), Decimal('3.4154')),
#  ('Caribbean', 'Puerto Rico', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('100.96'), Decimal('3.193354'), Decimal('3.4154')),
#  ('Caribbean', 'Puerto Rico', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('105.13'), Decimal('3.193694'), Decimal('3.7292')),
#  ('Caribbean', 'Barbados', 2019, Decimal('99.00'), Decimal('98.00'), Decimal('5.32'), Decimal('0.280180'), Decimal('3.7292')),
#  ('Caribbean', 'Jamaica', 2019, Decimal('90.33'), Decimal('87.00'), Decimal('15.83'), Decimal('2.813773'), Decimal('3.7292')),
#  ('Caribbean', 'Haiti', 2019, Decimal('64.67'), Decimal('36.00'), Decimal('14.79'), Decimal('11.160438'), Decimal('3.7292')),
#  ('Caribbean', 'Cuba', 2019, Decimal('96.33'), Decimal('90.00'), Decimal('103.43'), Decimal('11.316697'), Decimal('3.7292')),
#  ('Caribbean', 'Trinidad and Tobago', 2019, Decimal('99.00'), Decimal('94.00'), Decimal('23.85'), Decimal('1.519955'), Decimal('3.7292')),
#  ('Caribbean', 'Dominican Republic', 2019, Decimal('95.00'), Decimal('84.33'), Decimal('88.94'), Decimal('10.881882'), Decimal('3.7292')),
#  ('Caribbean', 'Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('103.02'), Decimal('3.281538'), Decimal('3.9777')),
#  ('Caribbean', 'Barbados', 2020, Decimal('99.00'), Decimal('98.00'), Decimal('4.67'), Decimal('0.280693'), Decimal('3.9777')),
#  ('Caribbean', 'Jamaica', 2020, Decimal('90.33'), Decimal('87.00'), Decimal('13.81'), Decimal('2.820436'), Decimal('3.9777')),
#  ('Caribbean', 'Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('14.51'), Decimal('11.306801'), Decimal('3.9777')),
#  ('Caribbean', 'Cuba', 2020, Decimal('96.33'), Decimal('90.00'), Decimal('107.35'), Decimal('11.300698'), Decimal('3.9777')),
#  ('Caribbean', 'Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), Decimal('21.06'), Decimal('1.518147'), Decimal('3.9777')),
#  ('Caribbean', 'Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), Decimal('78.84'), Decimal('10.999664'), Decimal('3.9777')),
#  ('Central America', 'Panama', 2015, Decimal('91.67'), Decimal('75.67'), Decimal('54.09'), Decimal('3.957099'), Decimal('20.8442')),
#  ('Central America', 'Nicaragua', 2015, Decimal('79.33'), Decimal('71.00'), Decimal('12.76'), Decimal('6.298598'), Decimal('20.8442')),
#  ('Central America', 'Mexico', 2015, Decimal('96.67'), Decimal('86.33'), Decimal('1171.87'), Decimal('120.149897'), Decimal('20.8442')),
#  ('Central America', 'Honduras', 2015, Decimal('92.67'), Decimal('78.67'), Decimal('20.98'), Decimal('9.294505'), Decimal('20.8442')),
#  ('Central America', 'Guatemala', 2015, Decimal('92.00'), Decimal('67.00'), Decimal('62.19'), Decimal('15.567419'), Decimal('20.8442')),
#  ('Central America', 'El Salvador', 2015, Decimal('94.33'), Decimal('81.00'), Decimal('23.44'), Decimal('6.231066'), Decimal('20.8442')),
#  ('Central America', 'Costa Rica', 2015, Decimal('99.00'), Decimal('96.33'), Decimal('56.44'), Decimal('4.895242'), Decimal('20.8442')),
#  ('Central America', 'Belize', 2015, Decimal('97.33'), Decimal('87.33'), Decimal('2.21'), Decimal('0.359871'), Decimal('20.8442')),
#  ('Central America', 'Panama', 2016, Decimal('91.67'), Decimal('76.67'), Decimal('57.91'), Decimal('4.026336'), Decimal('20.9713')),
#  ('Central America', 'Nicaragua', 2016, Decimal('79.00'), Decimal('71.67'), Decimal('13.29'), Decimal('6.389235'), Decimal('20.9713')),
#  ('Central America', 'Mexico', 2016, Decimal('97.33'), Decimal('87.33'), Decimal('1078.49'), Decimal('121.519221'), Decimal('20.9713')),
#  ('Central America', 'Honduras', 2016, Decimal('93.33'), Decimal('79.67'), Decimal('21.72'), Decimal('9.460798'), Decimal('20.9713')),
#  ('Central America', 'Guatemala', 2016, Decimal('92.33'), Decimal('67.00'), Decimal('66.05'), Decimal('15.827690'), Decimal('20.9713')),
#  ('Central America', 'El Salvador', 2016, Decimal('95.33'), Decimal('81.00'), Decimal('24.19'), Decimal('6.250510'), Decimal('20.9713')),
#  ('Central America', 'Costa Rica', 2016, Decimal('99.67'), Decimal('96.67'), Decimal('58.85'), Decimal('4.945205'), Decimal('20.9713')),
#  ('Central America', 'Belize', 2016, Decimal('97.67'), Decimal('88.00'), Decimal('2.26'), Decimal('0.367313'), Decimal('20.9713')),
#  ('Central America', 'Panama', 2017, Decimal('92.33'), Decimal('77.67'), Decimal('62.20'), Decimal('4.096063'), Decimal('21.0961')),
#  ('Central America', 'Nicaragua', 2017, Decimal('79.00'), Decimal('71.67'), Decimal('13.79'), Decimal('6.480532'), Decimal('21.0961')),
#  ('Central America', 'Mexico', 2017, Decimal('98.00'), Decimal('88.00'), Decimal('1158.91'), Decimal('122.839258'), Decimal('21.0961')),
#  ('Central America', 'Honduras', 2017, Decimal('93.67'), Decimal('80.67'), Decimal('23.14'), Decimal('9.626842'), Decimal('21.0961')),
#  ('Central America', 'Guatemala', 2017, Decimal('92.67'), Decimal('67.00'), Decimal('71.65'), Decimal('16.087418'), Decimal('21.0961')),
#  ('Central America', 'El Salvador', 2017, Decimal('96.00'), Decimal('80.67'), Decimal('24.98'), Decimal('6.266654'), Decimal('21.0961')),
#  ('Central America', 'Costa Rica', 2017, Decimal('100.00'), Decimal('96.67'), Decimal('60.52'), Decimal('4.993842'), Decimal('21.0961')),
#  ('Central America', 'Belize', 2017, Decimal('98.00'), Decimal('88.00'), Decimal('2.29'), Decimal('0.374693'), Decimal('21.0961')),
#  ('Central America', 'Panama', 2018, Decimal('92.33'), Decimal('78.67'), Decimal('64.93'), Decimal('4.165255'), Decimal('21.2155')),
#  ('Central America', 'Nicaragua', 2018, Decimal('79.33'), Decimal('71.67'), Decimal('13.03'), Decimal('6.572233'), Decimal('21.2155')),
#  ('Central America', 'Mexico', 2018, Decimal('98.33'), Decimal('89.00'), Decimal('1222.41'), Decimal('124.013861'), Decimal('21.2155')),
#  ('Central America', 'Honduras', 2018, Decimal('94.33'), Decimal('81.67'), Decimal('24.07'), Decimal('9.792850'), Decimal('21.2155')),
#  ('Central America', 'Guatemala', 2018, Decimal('93.00'), Decimal('67.33'), Decimal('73.33'), Decimal('16.346950'), Decimal('21.2155')),
#  ('Central America', 'El Salvador', 2018, Decimal('97.00'), Decimal('80.33'), Decimal('26.02'), Decimal('6.276342'), Decimal('21.2155')),
#  ('Central America', 'Costa Rica', 2018, Decimal('100.00'), Decimal('97.33'), Decimal('62.42'), Decimal('5.040734'), Decimal('21.2155')),
#  ('Central America', 'Belize', 2018, Decimal('98.33'), Decimal('88.67'), Decimal('2.31'), Decimal('0.382066'), Decimal('21.2155')),
#  ('Central America', 'Costa Rica', 2019, Decimal('100.00'), Decimal('97.33'), Decimal('64.42'), Decimal('5.084532'), Decimal('21.3299')),
#  ('Central America', 'Belize', 2019, Decimal('98.33'), Decimal('88.67'), Decimal('2.42'), Decimal('0.389095'), Decimal('21.3299')),
#  ('Central America', 'Panama', 2019, Decimal('92.67'), Decimal('79.67'), Decimal('66.98'), Decimal('4.232532'), Decimal('21.3299')),
#  ('Central America', 'Nicaragua', 2019, Decimal('79.33'), Decimal('71.67'), Decimal('12.60'), Decimal('6.663924'), Decimal('21.3299')),
#  ('Central America', 'Mexico', 2019, Decimal('98.67'), Decimal('90.00'), Decimal('1269.01'), Decimal('125.085311'), Decimal('21.3299')),
#  ('Central America', 'Honduras', 2019, Decimal('94.67'), Decimal('82.67'), Decimal('25.09'), Decimal('9.958829'), Decimal('21.3299')),
#  ('Central America', 'Guatemala', 2019, Decimal('94.00'), Decimal('67.67'), Decimal('77.17'), Decimal('16.604026'), Decimal('21.3299')),
#  ('Central America', 'El Salvador', 2019, Decimal('97.00'), Decimal('80.33'), Decimal('26.88'), Decimal('6.280217'), Decimal('21.3299')),
#  ('Central America', 'Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), Decimal('77.63'), Decimal('16.858333'), Decimal('21.4382')),
#  ('Central America', 'El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), Decimal('24.56'), Decimal('6.292731'), Decimal('21.4382')),
#  ('Central America', 'Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), Decimal('62.16'), Decimal('5.123105'), Decimal('21.4382')),
#  ('Central America', 'Belize', 2020, Decimal('98.33'), Decimal('88.67'), Decimal('2.08'), Decimal('0.394921'), Decimal('21.4382')),
#  ('Central America', 'Panama', 2020, Decimal('92.67'), Decimal('81.00'), Decimal('53.98'), Decimal('4.294396'), Decimal('21.4382')),
#  ('Central America', 'Nicaragua', 2020, Decimal('79.33'), Decimal('71.67'), Decimal('12.59'), Decimal('6.755895'), Decimal('21.4382')),
#  ('Central America', 'Mexico', 2020, Decimal('99.33'), Decimal('90.67'), Decimal('1090.52'), Decimal('125.998302'), Decimal('21.4382')),
#  ('Central America', 'Honduras', 2020, Decimal('95.33'), Decimal('83.33'), Decimal('23.83'), Decimal('10.121763'), Decimal('21.4382')),
#  ('Central Asia', 'Uzbekistan', 2015, Decimal('97.67'), Decimal('100.00'), Decimal('86.20'), Decimal('31.298900'), Decimal('15.7831')),
#  ('Central Asia', 'Turkmenistan', 2015, Decimal('97.67'), Decimal('97.33'), Decimal('35.80'), Decimal('5.766431'), Decimal('15.7831')),
#  ('Central Asia', 'Tajikistan', 2015, Decimal('80.33'), Decimal('95.00'), Decimal('8.27'), Decimal('8.524063'), Decimal('15.7831')),
#  ('Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('184.39'), Decimal('17.542806'), Decimal('15.7831')),
#  ('Central Asia', 'Uzbekistan', 2016, Decimal('97.67'), Decimal('100.00'), Decimal('86.14'), Decimal('31.847900'), Decimal('15.9210')),
#  ('Central Asia', 'Turkmenistan', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('36.17'), Decimal('5.868561'), Decimal('15.9210')),
#  ('Central Asia', 'Tajikistan', 2016, Decimal('81.33'), Decimal('95.33'), Decimal('6.99'), Decimal('8.725318'), Decimal('15.9210')),
#  ('Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('137.28'), Decimal('17.794055'), Decimal('15.9210')),
#  ('Central Asia', 'Uzbekistan', 2017, Decimal('98.00'), Decimal('100.00'), Decimal('62.08'), Decimal('32.388600'), Decimal('16.0574')),
#  ('Central Asia', 'Turkmenistan', 2017, Decimal('98.67'), Decimal('98.00'), Decimal('37.93'), Decimal('5.968383'), Decimal('16.0574')),
#  ('Central Asia', 'Tajikistan', 2017, Decimal('82.33'), Decimal('95.67'), Decimal('7.54'), Decimal('8.925525'), Decimal('16.0574')),
#  ('Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('166.81'), Decimal('18.037776'), Decimal('16.0574')),
#  ('Central Asia', 'Tajikistan', 2018, Decimal('83.33'), Decimal('95.67'), Decimal('7.77'), Decimal('9.128132'), Decimal('16.1946')),
#  ('Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('179.34'), Decimal('18.276452'), Decimal('16.1946')),
#  ('Central Asia', 'Uzbekistan', 2018, Decimal('98.00'), Decimal('100.00'), Decimal('52.63'), Decimal('32.956100'), Decimal('16.1946')),
#  ('Central Asia', 'Turkmenistan', 2018, Decimal('99.33'), Decimal('98.67'), Decimal('40.77'), Decimal('6.065066'), Decimal('16.1946')),
#  ('Central Asia', 'Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('45.23'), Decimal('6.158420'), Decimal('16.3352')),
#  ('Central Asia', 'Tajikistan', 2019, Decimal('85.00'), Decimal('96.33'), Decimal('8.30'), Decimal('9.337003'), Decimal('16.3352')),
#  ('Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('181.67'), Decimal('18.513673'), Decimal('16.3352')),
#  ('Central Asia', 'Uzbekistan', 2019, Decimal('98.00'), Decimal('100.00'), Decimal('59.91'), Decimal('33.580350'), Decimal('16.3352')),
#  ('Central Asia', 'Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), Decimal('34.232050'), Decimal('16.9232')),
#  ('Central Asia', 'Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), Decimal('9.543207'), Decimal('16.9232')),
#  ('Central Asia', 'Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), Decimal('18.755666'), Decimal('16.9232')),
#  ('Eastern Africa', 'Burundi', 2015, Decimal('68.33'), Decimal('44.67'), Decimal('3.10'), Decimal('10.727148'), Decimal('21.0161')),
#  ('Eastern Africa', 'Somalia', 2015, Decimal('50.67'), Decimal('35.67'), Decimal('5.33'), Decimal('13.763906'), Decimal('21.0161')),
#  ('Eastern Africa', 'Zambia', 2015, Decimal('63.67'), Decimal('31.00'), Decimal('21.25'), Decimal('16.248230'), Decimal('21.0161')),
#  ('Eastern Africa', 'Uganda', 2015, Decimal('55.00'), Decimal('21.33'), Decimal('32.39'), Decimal('37.477356'), Decimal('21.0161')),
#  ('Eastern Africa', 'Seychelles', 2015, Decimal('96.00'), Decimal('100.00'), Decimal('1.42'), Decimal('0.093419'), Decimal('21.0161')),
#  ('Eastern Africa', 'Rwanda', 2015, Decimal('63.00'), Decimal('61.00'), Decimal('8.54'), Decimal('11.642959'), Decimal('21.0161')),
#  ('Eastern Africa', 'Mozambique', 2015, Decimal('55.67'), Decimal('33.00'), Decimal('15.95'), Decimal('26.843246'), Decimal('21.0161')),
#  ('Eastern Africa', 'Mauritius', 2015, Decimal('100.00'), Decimal('95.67'), Decimal('12.01'), Decimal('1.262605'), Decimal('21.0161')),
#  ('Eastern Africa', 'Malawi', 2015, Decimal('71.33'), Decimal('27.67'), Decimal('6.37'), Decimal('16.938942'), Decimal('21.0161')),
#  ('Eastern Africa', 'Madagascar', 2015, Decimal('53.33'), Decimal('11.00'), Decimal('11.32'), Decimal('24.850912'), Decimal('21.0161')),
#  ('Eastern Africa', 'Kenya', 2015, Decimal('64.33'), Decimal('33.00'), Decimal('70.12'), Decimal('46.851488'), Decimal('21.0161')),
#  ('Eastern Africa', 'Ethiopia', 2015, Decimal('52.00'), Decimal('10.67'), Decimal('64.59'), Decimal('102.471895'), Decimal('21.0161')),
#  ('Eastern Africa', 'Djibouti', 2015, Decimal('69.67'), Decimal('51.33'), Decimal('2.42'), Decimal('1.006259'), Decimal('21.0161')),
#  ('Eastern Africa', 'Comoros', 2015, Decimal('81.67'), Decimal('37.67'), Decimal('0.97'), Decimal('0.730216'), Decimal('21.0161')),
#  ('Eastern Africa', 'South Sudan', 2015, Decimal('46.33'), Decimal('15.67'), Decimal('12.00'), Decimal('11.194299'), Decimal('21.0161')),
#  ('Eastern Africa', 'Zimbabwe', 2015, Decimal('70.00'), Decimal('40.00'), Decimal('19.96'), Decimal('14.154937'), Decimal('21.0161')),
#  ('Eastern Africa', 'Comoros', 2016, Decimal('81.67'), Decimal('37.67'), Decimal('1.01'), Decimal('0.746232'), Decimal('21.6217')),
#  ('Eastern Africa', 'Zimbabwe', 2016, Decimal('69.33'), Decimal('39.33'), Decimal('20.55'), Decimal('14.452704'), Decimal('21.6217')),
#  ('Eastern Africa', 'Burundi', 2016, Decimal('68.33'), Decimal('44.67'), Decimal('2.64'), Decimal('10.903327'), Decimal('21.6217')),
#  ('Eastern Africa', 'Somalia', 2016, Decimal('52.00'), Decimal('36.33'), Decimal('5.53'), Decimal('14.292847'), Decimal('21.6217')),
#  ('Eastern Africa', 'Zambia', 2016, Decimal('64.33'), Decimal('31.00'), Decimal('20.96'), Decimal('16.767761'), Decimal('21.6217')),
#  ('Eastern Africa', 'Uganda', 2016, Decimal('55.67'), Decimal('21.33'), Decimal('29.20'), Decimal('38.748299'), Decimal('21.6217')),
#  ('Eastern Africa', 'Seychelles', 2016, Decimal('96.00'), Decimal('100.00'), Decimal('1.49'), Decimal('0.094677'), Decimal('21.6217')),
#  ('Eastern Africa', 'Rwanda', 2016, Decimal('64.00'), Decimal('62.00'), Decimal('8.69'), Decimal('11.930899'), Decimal('21.6217')),
#  ('Eastern Africa', 'Mozambique', 2016, Decimal('58.00'), Decimal('34.67'), Decimal('11.94'), Decimal('27.696493'), Decimal('21.6217')),
#  ('Eastern Africa', 'Mauritius', 2016, Decimal('100.00'), Decimal('95.67'), Decimal('12.59'), Decimal('1.263473'), Decimal('21.6217')),
#  ('Eastern Africa', 'Malawi', 2016, Decimal('72.00'), Decimal('27.67'), Decimal('5.43'), Decimal('17.405624'), Decimal('21.6217')),
#  ('Eastern Africa', 'Madagascar', 2016, Decimal('54.00'), Decimal('11.67'), Decimal('11.85'), Decimal('25.501941'), Decimal('21.6217')),
#  ('Eastern Africa', 'Kenya', 2016, Decimal('65.00'), Decimal('33.00'), Decimal('74.82'), Decimal('47.894670'), Decimal('21.6217')),
#  ('Eastern Africa', 'Ethiopia', 2016, Decimal('53.33'), Decimal('11.00'), Decimal('74.30'), Decimal('105.293228'), Decimal('21.6217')),
#  ('Eastern Africa', 'Djibouti', 2016, Decimal('69.33'), Decimal('52.67'), Decimal('2.60'), Decimal('1.023261'), Decimal('21.6217')),
#  ('Eastern Africa', 'Djibouti', 2017, Decimal('69.33'), Decimal('53.67'), Decimal('2.76'), Decimal('1.040233'), Decimal('22.0354')),
#  ('Eastern Africa', 'Comoros', 2017, Decimal('81.67'), Decimal('37.67'), Decimal('1.08'), Decimal('0.761664'), Decimal('22.0354')),
#  ('Eastern Africa', 'Zimbabwe', 2017, Decimal('69.00'), Decimal('38.67'), Decimal('17.58'), Decimal('14.751101'), Decimal('22.0354')),
#  ('Eastern Africa', 'Burundi', 2017, Decimal('69.33'), Decimal('44.67'), Decimal('2.71'), Decimal('11.155593'), Decimal('22.0354')),
#  ('Eastern Africa', 'Somalia', 2017, Decimal('53.33'), Decimal('37.33'), Decimal('5.61'), Decimal('14.864221'), Decimal('22.0354')),
#  ('Eastern Africa', 'Zambia', 2017, Decimal('64.67'), Decimal('31.67'), Decimal('25.87'), Decimal('17.298054'), Decimal('22.0354')),
#  ('Eastern Africa', 'Uganda', 2017, Decimal('57.00'), Decimal('21.33'), Decimal('30.74'), Decimal('40.127085'), Decimal('22.0354')),
#  ('Eastern Africa', 'Seychelles', 2017, Decimal('96.00'), Decimal('100.00'), Decimal('1.57'), Decimal('0.095843'), Decimal('22.0354')),
#  ('Eastern Africa', 'Rwanda', 2017, Decimal('65.00'), Decimal('63.00'), Decimal('9.25'), Decimal('12.230339'), Decimal('22.0354')),
#  ('Eastern Africa', 'Mozambique', 2017, Decimal('60.00'), Decimal('35.67'), Decimal('13.22'), Decimal('28.569441'), Decimal('22.0354')),
#  ('Eastern Africa', 'Mauritius', 2017, Decimal('100.00'), Decimal('95.67'), Decimal('13.71'), Decimal('1.264613'), Decimal('22.0354')),
#  ('Eastern Africa', 'Malawi', 2017, Decimal('72.67'), Decimal('28.00'), Decimal('8.94'), Decimal('17.881167'), Decimal('22.0354')),
#  ('Eastern Africa', 'Madagascar', 2017, Decimal('54.67'), Decimal('12.00'), Decimal('13.18'), Decimal('26.169542'), Decimal('22.0354')),
#  ('Eastern Africa', 'Kenya', 2017, Decimal('65.67'), Decimal('33.00'), Decimal('82.04'), Decimal('48.948137'), Decimal('22.0354')),
#  ('Eastern Africa', 'Ethiopia', 2017, Decimal('54.67'), Decimal('11.00'), Decimal('81.77'), Decimal('108.197950'), Decimal('22.0354')),
#  ('Eastern Africa', 'Madagascar', 2018, Decimal('55.33'), Decimal('12.67'), Decimal('13.76'), Decimal('26.846541'), Decimal('22.3997')),
#  ('Eastern Africa', 'Kenya', 2018, Decimal('65.67'), Decimal('33.33'), Decimal('92.20'), Decimal('49.953304'), Decimal('22.3997')),
#  ('Eastern Africa', 'Ethiopia', 2018, Decimal('55.67'), Decimal('11.33'), Decimal('84.27'), Decimal('111.129438'), Decimal('22.3997')),
#  ('Eastern Africa', 'Djibouti', 2018, Decimal('69.33'), Decimal('54.67'), Decimal('2.91'), Decimal('1.057198'), Decimal('22.3997')),
#  ('Eastern Africa', 'Comoros', 2018, Decimal('81.67'), Decimal('37.67'), Decimal('1.19'), Decimal('0.776313'), Decimal('22.3997')),
#  ('Eastern Africa', 'Zimbabwe', 2018, Decimal('68.67'), Decimal('37.67'), Decimal('34.16'), Decimal('15.052184'), Decimal('22.3997')),
#  ('Eastern Africa', 'Burundi', 2018, Decimal('69.33'), Decimal('44.33'), Decimal('2.66'), Decimal('11.493472'), Decimal('22.3997')),
#  ('Eastern Africa', 'Somalia', 2018, Decimal('54.67'), Decimal('38.00'), Decimal('5.86'), Decimal('15.411094'), Decimal('22.3997')),
#  ('Eastern Africa', 'Zambia', 2018, Decimal('65.33'), Decimal('32.00'), Decimal('26.31'), Decimal('17.835893'), Decimal('22.3997')),
#  ('Eastern Africa', 'Uganda', 2018, Decimal('58.67'), Decimal('21.67'), Decimal('32.93'), Decimal('41.515395'), Decimal('22.3997')),
#  ('Eastern Africa', 'Seychelles', 2018, Decimal('96.00'), Decimal('100.00'), Decimal('1.64'), Decimal('0.096762'), Decimal('22.3997')),
#  ('Eastern Africa', 'Rwanda', 2018, Decimal('65.67'), Decimal('63.33'), Decimal('9.64'), Decimal('12.531808'), Decimal('22.3997')),
#  ('Eastern Africa', 'Mozambique', 2018, Decimal('62.33'), Decimal('37.33'), Decimal('14.85'), Decimal('29.423878'), Decimal('22.3997')),
#  ('Eastern Africa', 'Mauritius', 2018, Decimal('100.00'), Decimal('96.00'), Decimal('14.74'), Decimal('1.265303'), Decimal('22.3997')),
#  ('Eastern Africa', 'Malawi', 2018, Decimal('73.33'), Decimal('28.00'), Decimal('9.88'), Decimal('18.367883'), Decimal('22.3997')),
#  ('Eastern Africa', 'Mauritius', 2019, Decimal('100.00'), Decimal('96.00'), Decimal('14.44'), Decimal('1.265711'), Decimal('22.7467')),
#  ('Eastern Africa', 'Malawi', 2019, Decimal('73.67'), Decimal('28.33'), Decimal('11.03'), Decimal('18.867337'), Decimal('22.7467')),
#  ('Eastern Africa', 'Madagascar', 2019, Decimal('56.00'), Decimal('12.67'), Decimal('14.10'), Decimal('27.533134'), Decimal('22.7467')),
#  ('Eastern Africa', 'Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('100.38'), Decimal('50.951450'), Decimal('22.7467')),
#  ('Eastern Africa', 'Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('95.91'), Decimal('114.120594'), Decimal('22.7467')),
#  ('Eastern Africa', 'Djibouti', 2019, Decimal('69.00'), Decimal('56.00'), Decimal('3.09'), Decimal('1.073994'), Decimal('22.7467')),
#  ('Eastern Africa', 'Comoros', 2019, Decimal('81.67'), Decimal('37.67'), Decimal('1.20'), Decimal('0.790986'), Decimal('22.7467')),
#  ('Eastern Africa', 'Zimbabwe', 2019, Decimal('68.33'), Decimal('37.00'), Decimal('21.83'), Decimal('15.354608'), Decimal('22.7467')),
#  ('Eastern Africa', 'Burundi', 2019, Decimal('70.33'), Decimal('44.33'), Decimal('2.58'), Decimal('11.874838'), Decimal('22.7467')),
#  ('Eastern Africa', 'Somalia', 2019, Decimal('56.33'), Decimal('39.33'), Decimal('6.49'), Decimal('15.981300'), Decimal('22.7467')),
#  ('Eastern Africa', 'Zambia', 2019, Decimal('66.33'), Decimal('32.00'), Decimal('23.31'), Decimal('18.380477'), Decimal('22.7467')),
#  ('Eastern Africa', 'Uganda', 2019, Decimal('59.33'), Decimal('21.67'), Decimal('35.35'), Decimal('42.949080'), Decimal('22.7467')),
#  ('Eastern Africa', 'Seychelles', 2019, Decimal('97.00'), Decimal('100.00'), Decimal('1.68'), Decimal('0.097625'), Decimal('22.7467')),
#  ('Eastern Africa', 'Rwanda', 2019, Decimal('66.33'), Decimal('64.00'), Decimal('10.36'), Decimal('12.835028'), Decimal('22.7467')),
#  ('Eastern Africa', 'Mozambique', 2019, Decimal('64.33'), Decimal('39.33'), Decimal('15.39'), Decimal('30.285595'), Decimal('22.7467')),
#  ('Eastern Africa', 'Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), Decimal('13.146362'), Decimal('23.5951')),
#  ('Eastern Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), Decimal('31.178239'), Decimal('23.5951')),
#  ('Eastern Africa', 'Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), Decimal('1.265740'), Decimal('23.5951')),
#  ('Eastern Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), Decimal('19.377061'), Decimal('23.5951')),
#  ('Eastern Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('28.225177'), Decimal('23.5951')),
#  ('Eastern Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('51.985780'), Decimal('23.5951')),
#  ('Eastern Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('117.190911'), Decimal('23.5951')),
#  ('Eastern Africa', 'Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('1.090156'), Decimal('23.5951')),
#  ('Eastern Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), Decimal('15.669666'), Decimal('23.5951')),
#  ('Eastern Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('12.220227'), Decimal('23.5951')),
#  ('Eastern Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('16.537016'), Decimal('23.5951')),
#  ('Eastern Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), Decimal('18.927715'), Decimal('23.5951')),
#  ('Eastern Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), Decimal('44.404611'), Decimal('23.5951')),
#  ('Eastern Asia', 'Mongolia', 2015, Decimal('75.67'), Decimal('58.67'), Decimal('11.62'), Decimal('2.964749'), Decimal('503.3219')),
#  ('Eastern Asia', 'Japan', 2015, Decimal('99.00'), Decimal('100.00'), Decimal('4444.93'), Decimal('127.141000'), Decimal('503.3219')),
#  ('Eastern Asia', 'China', 2015, Decimal('91.33'), Decimal('83.67'), Decimal('11061.55'), Decimal('1379.860000'), Decimal('503.3219')),
#  ('Eastern Asia', 'Mongolia', 2016, Decimal('77.00'), Decimal('59.67'), Decimal('11.18'), Decimal('3.029555'), Decimal('504.6436')),
#  ('Eastern Asia', 'Japan', 2016, Decimal('99.00'), Decimal('100.00'), Decimal('5003.68'), Decimal('127.076000'), Decimal('504.6436')),
#  ('Eastern Asia', 'China', 2016, Decimal('91.33'), Decimal('85.67'), Decimal('11233.28'), Decimal('1387.790000'), Decimal('504.6436')),
#  ('Eastern Asia', 'China', 2017, Decimal('92.00'), Decimal('87.00'), Decimal('12310.41'), Decimal('1396.215000'), Decimal('506.0160')),
#  ('Eastern Asia', 'Mongolia', 2017, Decimal('78.00'), Decimal('61.00'), Decimal('11.48'), Decimal('3.096030'), Decimal('506.0160')),
#  ('Eastern Asia', 'Japan', 2017, Decimal('99.00'), Decimal('100.00'), Decimal('4930.84'), Decimal('126.972000'), Decimal('506.0160')),
#  ('Eastern Asia', 'Mongolia', 2018, Decimal('79.00'), Decimal('62.00'), Decimal('13.18'), Decimal('3.163991'), Decimal('507.2399')),
#  ('Eastern Asia', 'Japan', 2018, Decimal('99.00'), Decimal('100.00'), Decimal('5037.84'), Decimal('126.811000'), Decimal('507.2399')),
#  ('Eastern Asia', 'China', 2018, Decimal('92.67'), Decimal('88.33'), Decimal('13894.82'), Decimal('1402.760000'), Decimal('507.2399')),
#  ('Eastern Asia', 'Mongolia', 2019, Decimal('80.00'), Decimal('63.67'), Decimal('14.21'), Decimal('3.232430'), Decimal('508.2993')),
#  ('Eastern Asia', 'Japan', 2019, Decimal('99.00'), Decimal('100.00'), Decimal('5123.32'), Decimal('126.633000'), Decimal('508.2993')),
#  ('Eastern Asia', 'China', 2019, Decimal('93.33'), Decimal('90.33'), Decimal('14279.94'), Decimal('1407.745000'), Decimal('508.2993')),
#  ('Eastern Asia', 'Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('13.31'), Decimal('3.294335'), Decimal('509.1747')),
#  ('Eastern Asia', 'Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('5040.11'), Decimal('126.261000'), Decimal('509.1747')),
#  ('Eastern Asia', 'China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('14687.67'), Decimal('1411.100000'), Decimal('509.1747')),
#  ('Melanesia', 'Papua New Guinea', 2015, Decimal('53.67'), Decimal('28.33'), Decimal('21.72'), Decimal('8.682174'), Decimal('2.1516')),
#  ('Melanesia', 'New Caledonia', 2015, Decimal('98.00'), Decimal('100.00'), Decimal('8.74'), Decimal('0.269460'), Decimal('2.1516')),
#  ('Melanesia', 'Fiji', 2015, Decimal('93.67'), Decimal('96.00'), Decimal('4.68'), Decimal('0.917200'), Decimal('2.1516')),
#  ('Melanesia', 'Vanuatu', 2015, Decimal('92.00'), Decimal('56.00'), Decimal('0.73'), Decimal('0.276438'), Decimal('2.1516')),
#  ('Melanesia', 'Solomon Islands', 2015, Decimal('74.33'), Decimal('42.67'), Decimal('1.31'), Decimal('0.612660'), Decimal('2.1516')),
#  ('Melanesia', 'Vanuatu', 2016, Decimal('92.67'), Decimal('55.67'), Decimal('0.78'), Decimal('0.283218'), Decimal('2.1757')),
#  ('Melanesia', 'Solomon Islands', 2016, Decimal('74.00'), Decimal('43.33'), Decimal('1.38'), Decimal('0.628102'), Decimal('2.1757')),
#  ('Melanesia', 'Papua New Guinea', 2016, Decimal('54.33'), Decimal('28.00'), Decimal('20.76'), Decimal('8.899169'), Decimal('2.1757')),
#  ('Melanesia', 'New Caledonia', 2016, Decimal('98.00'), Decimal('100.00'), Decimal('8.72'), Decimal('0.270220'), Decimal('2.1757')),
#  ('Melanesia', 'Fiji', 2016, Decimal('93.67'), Decimal('97.33'), Decimal('4.93'), Decimal('0.918371'), Decimal('2.1757')),
#  ('Melanesia', 'Vanuatu', 2017, Decimal('93.00'), Decimal('55.67'), Decimal('0.88'), Decimal('0.290239'), Decimal('2.1997')),
#  ('Melanesia', 'Solomon Islands', 2017, Decimal('73.33'), Decimal('44.00'), Decimal('1.47'), Decimal('0.643634'), Decimal('2.1997')),
#  ('Melanesia', 'Papua New Guinea', 2017, Decimal('55.00'), Decimal('27.67'), Decimal('22.74'), Decimal('9.114796'), Decimal('2.1997')),
#  ('Melanesia', 'New Caledonia', 2017, Decimal('99.00'), Decimal('100.00'), Decimal('9.17'), Decimal('0.270810'), Decimal('2.1997')),
#  ('Melanesia', 'Fiji', 2017, Decimal('93.67'), Decimal('98.33'), Decimal('5.35'), Decimal('0.919019'), Decimal('2.1997')),
#  ('Melanesia', 'Vanuatu', 2018, Decimal('93.00'), Decimal('55.67'), Decimal('0.91'), Decimal('0.297298'), Decimal('2.2236')),
#  ('Melanesia', 'Solomon Islands', 2018, Decimal('72.33'), Decimal('44.33'), Decimal('1.62'), Decimal('0.659249'), Decimal('2.2236')),
#  ('Melanesia', 'Papua New Guinea', 2018, Decimal('55.67'), Decimal('27.67'), Decimal('24.11'), Decimal('9.329227'), Decimal('2.2236')),
#  ('Melanesia', 'New Caledonia', 2018, Decimal('99.00'), Decimal('100.00'), Decimal('9.85'), Decimal('0.271170'), Decimal('2.2236')),
#  ('Melanesia', 'Fiji', 2018, Decimal('93.67'), Decimal('99.00'), Decimal('5.58'), Decimal('0.918996'), Decimal('2.2236')),
#  ('Melanesia', 'Vanuatu', 2019, Decimal('93.00'), Decimal('55.67'), Decimal('0.94'), Decimal('0.304404'), Decimal('2.2473')),
#  ('Melanesia', 'Solomon Islands', 2019, Decimal('72.33'), Decimal('44.33'), Decimal('1.62'), Decimal('0.674993'), Decimal('2.2473')),
#  ('Melanesia', 'Papua New Guinea', 2019, Decimal('56.33'), Decimal('27.67'), Decimal('24.75'), Decimal('9.542486'), Decimal('2.2473')),
#  ('Melanesia', 'New Caledonia', 2019, Decimal('99.00'), Decimal('100.00'), Decimal('9.44'), Decimal('0.271230'), Decimal('2.2473')),
#  ('Melanesia', 'Fiji', 2019, Decimal('93.67'), Decimal('99.00'), Decimal('5.48'), Decimal('0.918465'), Decimal('2.2473')),
#  ('Melanesia', 'Vanuatu', 2020, Decimal('93.00'), Decimal('55.67'), Decimal('0.90'), Decimal('0.311685'), Decimal('2.2709')),
#  ('Melanesia', 'Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('1.54'), Decimal('0.691191'), Decimal('2.2709')),
#  ('Melanesia', 'Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('23.85'), Decimal('9.749640'), Decimal('2.2709')),
#  ('Melanesia', 'New Caledonia', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('9.44'), Decimal('0.271130'), Decimal('2.2709')),
#  ('Melanesia', 'Fiji', 2020, Decimal('93.67'), Decimal('99.00'), Decimal('4.48'), Decimal('0.920422'), Decimal('2.2709')),
#  ('Micronesia', 'Palau', 2015, Decimal('100.00'), Decimal('98.33'), Decimal('0.28'), Decimal('0.017794'), Decimal('0.0691')),
#  ('Micronesia', 'Northern Mariana Islands', 2015, Decimal('100.00'), Decimal('78.00'), Decimal('0.91'), Decimal('0.051514'), Decimal('0.0691')),
#  ('Micronesia', 'Nauru', 2015, Decimal('100.00'), Decimal('66.00'), Decimal('0.09'), Decimal('0.011185'), Decimal('0.0691')),
#  ('Micronesia', 'Marshall Islands', 2015, Decimal('89.33'), Decimal('77.67'), Decimal('0.18'), Decimal('0.049410'), Decimal('0.0691')),
#  ('Micronesia', 'Kiribati', 2015, Decimal('73.67'), Decimal('43.00'), Decimal('0.17'), Decimal('0.116707'), Decimal('0.0691')),
#  ('Micronesia', 'Guam', 2015, Decimal('100.00'), Decimal('90.00'), Decimal('5.80'), Decimal('0.167978'), Decimal('0.0691')),
#  ('Micronesia', 'Guam', 2016, Decimal('100.00'), Decimal('90.00'), Decimal('5.90'), Decimal('0.168346'), Decimal('0.0692')),
#  ('Micronesia', 'Palau', 2016, Decimal('100.00'), Decimal('99.00'), Decimal('0.30'), Decimal('0.017816'), Decimal('0.0692')),
#  ('Micronesia', 'Northern Mariana Islands', 2016, Decimal('100.00'), Decimal('79.00'), Decimal('1.23'), Decimal('0.051133'), Decimal('0.0692')),
#  ('Micronesia', 'Nauru', 2016, Decimal('100.00'), Decimal('66.00'), Decimal('0.10'), Decimal('0.011437'), Decimal('0.0692')),
#  ('Micronesia', 'Marshall Islands', 2016, Decimal('89.67'), Decimal('77.67'), Decimal('0.20'), Decimal('0.048329'), Decimal('0.0692')),
#  ('Micronesia', 'Kiribati', 2016, Decimal('74.33'), Decimal('43.67'), Decimal('0.18'), Decimal('0.118513'), Decimal('0.0692')),
#  ('Micronesia', 'Marshall Islands', 2017, Decimal('89.67'), Decimal('78.00'), Decimal('0.21'), Decimal('0.047187'), Decimal('0.0693')),
#  ('Micronesia', 'Kiribati', 2017, Decimal('75.00'), Decimal('44.00'), Decimal('0.19'), Decimal('0.120362'), Decimal('0.0693')),
#  ('Micronesia', 'Guam', 2017, Decimal('100.00'), None, Decimal('6.01'), Decimal('0.168606'), Decimal('0.0693')),
#  ('Micronesia', 'Palau', 2017, Decimal('100.00'), Decimal('99.67'), Decimal('0.29'), Decimal('0.017837'), Decimal('0.0693')),
#  ('Micronesia', 'Northern Mariana Islands', 2017, Decimal('100.00'), Decimal('79.00'), Decimal('1.56'), Decimal('0.050729'), Decimal('0.0693')),
#  ('Micronesia', 'Nauru', 2017, Decimal('100.00'), Decimal('66.00'), Decimal('0.11'), Decimal('0.011682'), Decimal('0.0693')),
#  ('Micronesia', 'Northern Mariana Islands', 2018, Decimal('100.00'), Decimal('79.00'), Decimal('1.30'), Decimal('0.050304'), Decimal('0.0693')),
#  ('Micronesia', 'Nauru', 2018, Decimal('100.00'), None, Decimal('0.12'), Decimal('0.011924'), Decimal('0.0693')),
#  ('Micronesia', 'Marshall Islands', 2018, Decimal('90.00'), Decimal('78.00'), Decimal('0.22'), Decimal('0.045989'), Decimal('0.0693')),
#  ('Micronesia', 'Kiribati', 2018, Decimal('75.33'), Decimal('44.33'), Decimal('0.20'), Decimal('0.122261'), Decimal('0.0693')),
#  ('Micronesia', 'Guam', 2018, Decimal('100.00'), None, Decimal('6.06'), Decimal('0.168678'), Decimal('0.0693')),
#  ('Micronesia', 'Palau', 2018, Decimal('100.00'), Decimal('99.67'), Decimal('0.28'), Decimal('0.017864'), Decimal('0.0693')),
#  ('Micronesia', 'Palau', 2019, Decimal('100.00'), Decimal('99.67'), Decimal('0.28'), Decimal('0.017916'), Decimal('0.0694')),
#  ('Micronesia', 'Northern Mariana Islands', 2019, Decimal('100.00'), Decimal('79.00'), Decimal('1.18'), Decimal('0.049858'), Decimal('0.0694')),
#  ('Micronesia', 'Nauru', 2019, Decimal('100.00'), None, Decimal('0.12'), Decimal('0.012132'), Decimal('0.0694')),
#  ('Micronesia', 'Marshall Islands', 2019, Decimal('90.00'), Decimal('78.00'), Decimal('0.23'), Decimal('0.044728'), Decimal('0.0694')),
#  ('Micronesia', 'Kiribati', 2019, Decimal('76.00'), Decimal('44.67'), Decimal('0.18'), Decimal('0.124241'), Decimal('0.0694')),
#  ('Micronesia', 'Guam', 2019, Decimal('100.00'), None, Decimal('6.37'), Decimal('0.168624'), Decimal('0.0694')),
#  ('Micronesia', 'Palau', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('0.25'), Decimal('0.017972'), Decimal('0.0700')),
#  ('Micronesia', 'Nauru', 2020, Decimal('100.00'), None, Decimal('0.11'), Decimal('0.012315'), Decimal('0.0700')),
#  ('Micronesia', 'Marshall Islands', 2020, Decimal('90.00'), Decimal('78.00'), Decimal('0.24'), Decimal('0.043413'), Decimal('0.0700')),
#  ('Micronesia', 'Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.18'), Decimal('0.126463'), Decimal('0.0700')),
#  ('Micronesia', 'Guam', 2020, Decimal('100.00'), None, Decimal('5.89'), Decimal('0.169231'), Decimal('0.0700')),
#  ('Middle Africa', 'Sao Tome and Principe', 2015, Decimal('76.00'), Decimal('39.00'), Decimal('0.32'), Decimal('0.201124'), Decimal('10.5252')),
#  ('Middle Africa', 'Gabon', 2015, Decimal('72.00'), Decimal('46.33'), Decimal('14.38'), Decimal('2.028517'), Decimal('10.5252')),
#  ('Middle Africa', 'Equatorial Guinea', 2015, Decimal('57.67'), Decimal('64.33'), Decimal('13.19'), Decimal('1.346973'), Decimal('10.5252')),
#  ('Middle Africa', 'Chad', 2015, Decimal('51.67'), Decimal('16.33'), Decimal('10.95'), Decimal('14.140274'), Decimal('10.5252')),
#  ('Middle Africa', 'Central African Republic', 2015, Decimal('44.00'), Decimal('17.33'), Decimal('1.70'), Decimal('4.819333'), Decimal('10.5252')),
#  ('Middle Africa', 'Cameroon', 2015, Decimal('62.67'), Decimal('41.67'), Decimal('32.21'), Decimal('23.012646'), Decimal('10.5252')),
#  ('Middle Africa', 'Angola', 2015, Decimal('50.33'), Decimal('43.33'), Decimal('87.22'), Decimal('28.127721'), Decimal('10.5252')),
#  ('Middle Africa', 'Cameroon', 2016, Decimal('62.67'), Decimal('41.67'), Decimal('33.81'), Decimal('23.711630'), Decimal('10.6950')),
#  ('Middle Africa', 'Angola', 2016, Decimal('51.00'), Decimal('44.67'), Decimal('49.84'), Decimal('29.154746'), Decimal('10.6950')),
#  ('Middle Africa', 'Sao Tome and Principe', 2016, Decimal('76.67'), Decimal('40.33'), Decimal('0.35'), Decimal('0.204632'), Decimal('10.6950')),
#  ('Middle Africa', 'Gabon', 2016, Decimal('72.33'), Decimal('46.33'), Decimal('14.02'), Decimal('2.086206'), Decimal('10.6950')),
#  ('Middle Africa', 'Equatorial Guinea', 2016, Decimal('57.67'), Decimal('64.33'), Decimal('11.24'), Decimal('1.398927'), Decimal('10.6950')),
#  ('Middle Africa', 'Chad', 2016, Decimal('52.00'), Decimal('16.67'), Decimal('10.10'), Decimal('14.592585'), Decimal('10.6950')),
#  ('Middle Africa', 'Central African Republic', 2016, Decimal('42.67'), Decimal('17.00'), Decimal('1.83'), Decimal('4.904177'), Decimal('10.6950')),
#  ('Middle Africa', 'Chad', 2017, Decimal('52.00'), Decimal('17.00'), Decimal('10.00'), Decimal('15.085884'), Decimal('10.8673')),
#  ('Middle Africa', 'Central African Republic', 2017, Decimal('41.33'), Decimal('16.67'), Decimal('2.07'), Decimal('4.996741'), Decimal('10.8673')),
#  ('Middle Africa', 'Cameroon', 2017, Decimal('63.33'), Decimal('42.00'), Decimal('36.10'), Decimal('24.393181'), Decimal('10.8673')),
#  ('Middle Africa', 'Angola', 2017, Decimal('51.33'), Decimal('45.67'), Decimal('68.97'), Decimal('30.208628'), Decimal('10.8673')),
#  ('Middle Africa', 'Sao Tome and Principe', 2017, Decimal('77.00'), Decimal('41.33'), Decimal('0.38'), Decimal('0.208036'), Decimal('10.8673')),
#  ('Middle Africa', 'Gabon', 2017, Decimal('73.00'), Decimal('46.33'), Decimal('14.93'), Decimal('2.140215'), Decimal('10.8673')),
#  ('Middle Africa', 'Equatorial Guinea', 2017, Decimal('58.00'), Decimal('64.33'), Decimal('12.20'), Decimal('1.450694'), Decimal('10.8673')),
#  ('Middle Africa', 'Chad', 2018, Decimal('52.00'), Decimal('17.67'), Decimal('11.24'), Decimal('15.604210'), Decimal('11.3950')),
#  ('Middle Africa', 'Central African Republic', 2018, Decimal('40.67'), Decimal('16.00'), Decimal('2.22'), Decimal('5.094780'), Decimal('11.3950')),
#  ('Middle Africa', 'Cameroon', 2018, Decimal('63.33'), Decimal('42.33'), Decimal('39.97'), Decimal('25.076747'), Decimal('11.3950')),
#  ('Middle Africa', 'Angola', 2018, Decimal('52.33'), Decimal('46.67'), Decimal('77.79'), Decimal('31.273533'), Decimal('11.3950')),
#  ('Middle Africa', 'Sao Tome and Principe', 2018, Decimal('77.00'), Decimal('42.67'), Decimal('0.41'), Decimal('0.211344'), Decimal('11.3950')),
#  ('Middle Africa', 'Gabon', 2018, Decimal('73.00'), Decimal('46.67'), Decimal('16.87'), Decimal('2.192012'), Decimal('11.3950')),
#  ('Middle Africa', 'Chad', 2019, Decimal('52.33'), Decimal('18.33'), Decimal('11.31'), Decimal('16.126866'), Decimal('11.8059')),
#  ('Middle Africa', 'Central African Republic', 2019, Decimal('39.33'), Decimal('15.33'), Decimal('2.22'), Decimal('5.209324'), Decimal('11.8059')),
#  ('Middle Africa', 'Cameroon', 2019, Decimal('63.33'), Decimal('42.33'), Decimal('39.67'), Decimal('25.782341'), Decimal('11.8059')),
#  ('Middle Africa', 'Angola', 2019, Decimal('52.33'), Decimal('46.67'), Decimal('69.31'), Decimal('32.353588'), Decimal('11.8059')),
#  ('Middle Africa', 'Sao Tome and Principe', 2019, Decimal('77.33'), Decimal('44.33'), Decimal('0.43'), Decimal('0.214599'), Decimal('11.8059')),
#  ('Middle Africa', 'Gabon', 2019, Decimal('73.33'), Decimal('47.00'), Decimal('16.87'), Decimal('2.242785'), Decimal('11.8059')),
#  ('Middle Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('16.644701'), Decimal('12.1542')),
#  ('Middle Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('5.343020'), Decimal('12.1542')),
#  ('Middle Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), Decimal('26.491087'), Decimal('12.1542')),
#  ('Middle Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), Decimal('33.428486'), Decimal('12.1542')),
#  ('Middle Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), Decimal('0.218641'), Decimal('12.1542')),
#  ('Middle Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), Decimal('2.292573'), Decimal('12.1542')),
#  ('Northern Africa', 'Tunisia', 2015, Decimal('93.33'), Decimal('90.33'), Decimal('45.78'), Decimal('11.557779'), Decimal('26.0290')),
# ...
#  ('Western Africa', 'Ghana', 2018, Decimal('82.67'), Decimal('21.67'), Decimal('67.30'), Decimal('30.870641'), Decimal('24.7165')),
#  ('Western Africa', 'Guinea-Bissau', 2019, Decimal('60.00'), Decimal('18.33'), Decimal('1.44'), Decimal('1.970457'), Decimal('25.0470')),
#  ('Western Africa', 'Guinea', 2019, Decimal('67.00'), Decimal('30.67'), Decimal('13.44'), Decimal('12.877539'), Decimal('25.0470')),
#  ('Western Africa', 'Ghana', 2019, Decimal('83.67'), Decimal('22.67'), Decimal('68.34'), Decimal('31.522290'), Decimal('25.0470')),
#  ('Western Africa', 'Cabo Verde', 2019, Decimal('86.67'), Decimal('76.00'), Decimal('1.98'), Decimal('0.577030'), Decimal('25.0470')),
#  ('Western Africa', 'Burkina Faso', 2019, Decimal('54.00'), Decimal('25.00'), Decimal('16.18'), Decimal('20.951639'), Decimal('25.0470')),
#  ('Western Africa', 'Benin', 2019, Decimal('65.33'), Decimal('17.00'), Decimal('14.39'), Decimal('12.290444'), Decimal('25.0470')),
#  ('Western Africa', 'Togo', 2019, Decimal('70.33'), Decimal('19.67'), Decimal('7.22'), Decimal('8.243094'), Decimal('25.0470')),
#  ('Western Africa', 'Sierra Leone', 2019, Decimal('64.00'), Decimal('17.00'), Decimal('4.08'), Decimal('8.046828'), Decimal('25.0470')),
#  ('Western Africa', 'Senegal', 2019, Decimal('84.00'), Decimal('56.33'), Decimal('23.40'), Decimal('16.000781'), Decimal('25.0470')),
#  ('Western Africa', 'Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('448.12'), Decimal('203.304492'), Decimal('25.0470')),
#  ('Western Africa', 'Niger', 2019, Decimal('57.33'), Decimal('23.67'), Decimal('12.92'), Decimal('23.443393'), Decimal('25.0470')),
#  ('Western Africa', 'Mauritania', 2019, Decimal('70.00'), Decimal('47.67'), Decimal('8.07'), Decimal('4.383849'), Decimal('25.0470')),
#  ('Western Africa', 'Mali', 2019, Decimal('82.00'), Decimal('44.67'), Decimal('17.28'), Decimal('20.567424'), Decimal('25.0470')),
#  ('Western Africa', 'Liberia', 2019, Decimal('75.00'), Decimal('17.67'), Decimal('3.32'), Decimal('4.985289'), Decimal('25.0470')),
#  ('Western Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), Decimal('21.224040'), Decimal('25.3812')),
#  ('Western Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('5.087584'), Decimal('25.3812')),
#  ('Western Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('2.015828'), Decimal('25.3812')),
#  ('Western Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('13.205153'), Decimal('25.3812')),
#  ('Western Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('32.180401'), Decimal('25.3812')),
#  ('Western Africa', 'Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('0.582640'), Decimal('25.3812')),
#  ('Western Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('21.522626'), Decimal('25.3812')),
#  ('Western Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('12.643123'), Decimal('25.3812')),
#  ('Western Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), Decimal('8.442580'), Decimal('25.3812')),
#  ('Western Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), Decimal('8.233970'), Decimal('25.3812')),
#  ('Western Africa', 'Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), Decimal('16.436120'), Decimal('25.3812')),
#  ('Western Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), Decimal('208.327405'), Decimal('25.3812')),
#  ('Western Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('24.333639'), Decimal('25.3812')),
#  ('Western Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), Decimal('4.498604'), Decimal('25.3812')),
#  ('Western Asia', 'Armenia', 2015, Decimal('99.67'), Decimal('91.33'), Decimal('10.55'), Decimal('2.878595'), Decimal('10.1481')),
#  ('Western Asia', 'Qatar', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('161.74'), Decimal('2.414573'), Decimal('10.1481')),
#  ('Western Asia', 'United Arab Emirates', 2015, Decimal('100.00'), Decimal('99.00'), Decimal('370.28'), Decimal('8.916899'), Decimal('10.1481')),
#  ('Western Asia', 'Oman', 2015, Decimal('86.00'), Decimal('99.00'), Decimal('78.71'), Decimal('4.191776'), Decimal('10.1481')),
#  ('Western Asia', 'Syrian Arab Republic', 2015, Decimal('93.33'), Decimal('90.00'), Decimal('16.47'), Decimal('19.205178'), Decimal('10.1481')),
#  ('Western Asia', 'Lebanon', 2015, Decimal('91.00'), Decimal('94.00'), Decimal('49.93'), Decimal('6.398940'), Decimal('10.1481')),
#  ('Western Asia', 'Saudi Arabia', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('654.27'), Decimal('32.749848'), Decimal('10.1481')),
#  ('Western Asia', 'Kuwait', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('114.57'), Decimal('3.908743'), Decimal('10.1481')),
#  ('Western Asia', 'Jordan', 2015, Decimal('98.33'), Decimal('97.00'), Decimal('38.59'), Decimal('9.494246'), Decimal('10.1481')),
#  ('Western Asia', 'Israel', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('303.41'), Decimal('8.380100'), Decimal('10.1481')),
#  ('Western Asia', 'Iraq', 2015, Decimal('92.33'), Decimal('92.00'), Decimal('166.77'), Decimal('37.757813'), Decimal('10.1481')),
#  ('Western Asia', 'Georgia', 2015, Decimal('95.33'), Decimal('85.67'), Decimal('14.95'), Decimal('3.725276'), Decimal('10.1481')),
#  ('Western Asia', 'Cyprus', 2015, Decimal('100.00'), Decimal('99.33'), Decimal('19.91'), Decimal('1.187280'), Decimal('10.1481')),
#  ('Western Asia', 'Bahrain', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('31.05'), Decimal('1.362142'), Decimal('10.1481')),
#  ('Western Asia', 'Azerbaijan', 2015, Decimal('91.67'), Decimal('96.00'), Decimal('53.07'), Decimal('9.649341'), Decimal('10.1481')),
#  ('Western Asia', 'Bahrain', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('32.23'), Decimal('1.409661'), Decimal('10.2354')),
#  ('Western Asia', 'Azerbaijan', 2016, Decimal('92.33'), Decimal('96.00'), Decimal('37.87'), Decimal('9.757812'), Decimal('10.2354')),
#  ('Western Asia', 'Armenia', 2016, Decimal('99.67'), Decimal('91.67'), Decimal('10.55'), Decimal('2.865835'), Decimal('10.2354')),
#  ('Western Asia', 'Qatar', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('151.73'), Decimal('2.595166'), Decimal('10.2354')),
#  ('Western Asia', 'United Arab Emirates', 2016, Decimal('100.00'), Decimal('99.00'), Decimal('369.26'), Decimal('8.994263'), Decimal('10.2354')),
#  ('Western Asia', 'Oman', 2016, Decimal('86.67'), Decimal('99.00'), Decimal('75.13'), Decimal('4.398070'), Decimal('10.2354')),
#  ('Western Asia', 'Syrian Arab Republic', 2016, Decimal('93.67'), Decimal('90.00'), Decimal('12.60'), Decimal('18.964252'), Decimal('10.2354')),
#  ('Western Asia', 'Lebanon', 2016, Decimal('92.00'), Decimal('95.00'), Decimal('51.15'), Decimal('6.258619'), Decimal('10.2354')),
#  ('Western Asia', 'Saudi Arabia', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('644.94'), Decimal('33.416270'), Decimal('10.2354')),
#  ('Western Asia', 'Kuwait', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('109.42'), Decimal('4.048085'), Decimal('10.2354')),
#  ('Western Asia', 'Jordan', 2016, Decimal('98.33'), Decimal('97.00'), Decimal('39.89'), Decimal('9.964656'), Decimal('10.2354')),
#  ('Western Asia', 'Israel', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('322.10'), Decimal('8.546000'), Decimal('10.2354')),
#  ('Western Asia', 'Iraq', 2016, Decimal('93.67'), Decimal('94.33'), Decimal('166.60'), Decimal('38.697943'), Decimal('10.2354')),
#  ('Western Asia', 'Georgia', 2016, Decimal('96.00'), Decimal('85.00'), Decimal('15.14'), Decimal('3.727505'), Decimal('10.2354')),
#  ('Western Asia', 'Cyprus', 2016, Decimal('100.00'), Decimal('99.33'), Decimal('21.05'), Decimal('1.197881'), Decimal('10.2354')),
#  ('Western Asia', 'Iraq', 2017, Decimal('94.67'), Decimal('96.00'), Decimal('187.22'), Decimal('39.621162'), Decimal('10.3210')),
#  ('Western Asia', 'Georgia', 2017, Decimal('96.67'), Decimal('85.33'), Decimal('16.24'), Decimal('3.728004'), Decimal('10.3210')),
#  ('Western Asia', 'Cyprus', 2017, Decimal('100.00'), Decimal('99.33'), Decimal('22.95'), Decimal('1.208523'), Decimal('10.3210')),
#  ('Western Asia', 'Bahrain', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('35.47'), Decimal('1.456834'), Decimal('10.3210')),
#  ('Western Asia', 'Azerbaijan', 2017, Decimal('93.67'), Decimal('96.00'), Decimal('40.87'), Decimal('9.854033'), Decimal('10.3210')),
#  ('Western Asia', 'Armenia', 2017, Decimal('100.00'), Decimal('92.00'), Decimal('11.53'), Decimal('2.851923'), Decimal('10.3210')),
#  ('Western Asia', 'United Arab Emirates', 2017, Decimal('100.00'), Decimal('99.00'), Decimal('390.52'), Decimal('9.068296'), Decimal('10.3210')),
#  ('Western Asia', 'Oman', 2017, Decimal('86.67'), Decimal('99.00'), Decimal('80.86'), Decimal('4.541854'), Decimal('10.3210')),
#  ('Western Asia', 'Syrian Arab Republic', 2017, Decimal('93.67'), Decimal('90.00'), Decimal('16.37'), Decimal('18.983373'), Decimal('10.3210')),
#  ('Western Asia', 'Lebanon', 2017, Decimal('92.00'), Decimal('97.00'), Decimal('53.03'), Decimal('6.109252'), Decimal('10.3210')),
#  ('Western Asia', 'Saudi Arabia', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('688.59'), Decimal('34.193122'), Decimal('10.3210')),
#  ('Western Asia', 'Kuwait', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('120.71'), Decimal('4.124904'), Decimal('10.3210')),
#  ('Western Asia', 'Qatar', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('161.10'), Decimal('2.711755'), Decimal('10.3210')),
#  ('Western Asia', 'Jordan', 2017, Decimal('98.33'), Decimal('96.67'), Decimal('41.61'), Decimal('10.215381'), Decimal('10.3210')),
#  ('Western Asia', 'Israel', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('358.25'), Decimal('8.713300'), Decimal('10.3210')),
#  ('Western Asia', 'Qatar', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('183.33'), Decimal('2.766732'), Decimal('10.4119')),
#  ('Western Asia', 'Jordan', 2018, Decimal('98.33'), Decimal('96.67'), Decimal('43.37'), Decimal('10.459865'), Decimal('10.4119')),
#  ('Western Asia', 'Israel', 2018, Decimal('100.00'), Decimal('99.67'), Decimal('376.69'), Decimal('8.882800'), Decimal('10.4119')),
#  ('Western Asia', 'Iraq', 2018, Decimal('95.67'), Decimal('97.67'), Decimal('227.37'), Decimal('40.590700'), Decimal('10.4119')),
#  ('Western Asia', 'Georgia', 2018, Decimal('96.67'), Decimal('85.00'), Decimal('17.60'), Decimal('3.726549'), Decimal('10.4119')),
#  ('Western Asia', 'Cyprus', 2018, Decimal('100.00'), Decimal('99.33'), Decimal('25.60'), Decimal('1.218831'), Decimal('10.4119')),
#  ('Western Asia', 'Bahrain', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('37.80'), Decimal('1.487340'), Decimal('10.4119')),
#  ('Western Asia', 'Azerbaijan', 2018, Decimal('94.33'), Decimal('96.00'), Decimal('47.11'), Decimal('9.939771'), Decimal('10.4119')),
#  ('Western Asia', 'Armenia', 2018, Decimal('100.00'), Decimal('92.33'), Decimal('12.46'), Decimal('2.836557'), Decimal('10.4119')),
#  ('Western Asia', 'United Arab Emirates', 2018, Decimal('100.00'), Decimal('99.00'), Decimal('427.05'), Decimal('9.140169'), Decimal('10.4119')),
#  ('Western Asia', 'Oman', 2018, Decimal('87.00'), Decimal('99.00'), Decimal('91.51'), Decimal('4.601157'), Decimal('10.4119')),
#  ('Western Asia', 'Syrian Arab Republic', 2018, Decimal('93.67'), Decimal('89.67'), Decimal('21.35'), Decimal('19.333463'), Decimal('10.4119')),
#  ('Western Asia', 'Lebanon', 2018, Decimal('92.00'), Decimal('98.00'), Decimal('54.90'), Decimal('5.950839'), Decimal('10.4119')),
#  ('Western Asia', 'Saudi Arabia', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('816.58'), Decimal('35.018133'), Decimal('10.4119')),
#  ('Western Asia', 'Kuwait', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('138.18'), Decimal('4.317185'), Decimal('10.4119')),
#  ('Western Asia', 'Oman', 2019, Decimal('87.67'), Decimal('99.00'), Decimal('88.06'), Decimal('4.602768'), Decimal('10.5079')),
#  ('Western Asia', 'Syrian Arab Republic', 2019, Decimal('93.67'), Decimal('90.00'), Decimal('22.44'), Decimal('20.098251'), Decimal('10.5079')),
#  ('Western Asia', 'Lebanon', 2019, Decimal('93.00'), Decimal('99.00'), Decimal('51.95'), Decimal('5.781907'), Decimal('10.5079')),
#  ('Western Asia', 'Saudi Arabia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('803.62'), Decimal('35.827362'), Decimal('10.5079')),
#  ('Western Asia', 'Kuwait', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('136.20'), Decimal('4.441100'), Decimal('10.5079')),
#  ('Western Asia', 'Qatar', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('175.84'), Decimal('2.807235'), Decimal('10.5079')),
#  ('Western Asia', 'Jordan', 2019, Decimal('98.33'), Decimal('96.33'), Decimal('44.99'), Decimal('10.698683'), Decimal('10.5079')),
#  ('Western Asia', 'Israel', 2019, Decimal('100.00'), Decimal('99.67'), Decimal('402.47'), Decimal('9.054000'), Decimal('10.5079')),
#  ('Western Asia', 'Iraq', 2019, Decimal('97.00'), Decimal('99.33'), Decimal('233.64'), Decimal('41.563520'), Decimal('10.5079')),
#  ('Western Asia', 'Georgia', 2019, Decimal('96.67'), Decimal('84.67'), Decimal('17.47'), Decimal('3.720161'), Decimal('10.5079')),
#  ('Western Asia', 'Cyprus', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('25.94'), Decimal('1.228836'), Decimal('10.5079')),
#  ('Western Asia', 'Bahrain', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('38.65'), Decimal('1.494188'), Decimal('10.5079')),
#  ('Western Asia', 'Azerbaijan', 2019, Decimal('95.00'), Decimal('96.00'), Decimal('48.17'), Decimal('10.024283'), Decimal('10.5079')),
#  ('Western Asia', 'Armenia', 2019, Decimal('100.00'), Decimal('92.33'), Decimal('13.62'), Decimal('2.820602'), Decimal('10.5079')),
#  ('Western Asia', 'United Arab Emirates', 2019, Decimal('100.00'), Decimal('99.00'), Decimal('417.99'), Decimal('9.211657'), Decimal('10.5079')),
#  ('Western Asia', 'United Arab Emirates', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('349.47'), Decimal('9.287289'), Decimal('10.5946')),
#  ('Western Asia', 'Oman', 2020, Decimal('87.67'), Decimal('99.00'), Decimal('75.91'), Decimal('4.543399'), Decimal('10.5946')),
#  ('Western Asia', 'Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('90.00'), Decimal('11.08'), Decimal('20.772595'), Decimal('10.5946')),
#  ('Western Asia', 'Lebanon', 2020, Decimal('93.00'), Decimal('99.00'), Decimal('31.71'), Decimal('5.662923'), Decimal('10.5946')),
#  ('Western Asia', 'Saudi Arabia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('703.37'), Decimal('35.997107'), Decimal('10.5946')),
#  ('Western Asia', 'Kuwait', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('105.96'), Decimal('4.360444'), Decimal('10.5946')),
#  ('Western Asia', 'Qatar', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('144.41'), Decimal('2.760385'), Decimal('10.5946')),
#  ('Western Asia', 'Jordan', 2020, Decimal('98.33'), Decimal('96.33'), Decimal('44.18'), Decimal('10.928721'), Decimal('10.5946')),
#  ('Western Asia', 'Israel', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('413.27'), Decimal('9.215100'), Decimal('10.5946')),
#  ('Western Asia', 'Iraq', 2020, Decimal('97.67'), Decimal('100.00'), Decimal('184.37'), Decimal('42.556984'), Decimal('10.5946')),
#  ('Western Asia', 'Georgia', 2020, Decimal('96.67'), Decimal('84.33'), Decimal('15.84'), Decimal('3.722716'), Decimal('10.5946')),
#  ('Western Asia', 'Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('25.01'), Decimal('1.237537'), Decimal('10.5946')),
#  ('Western Asia', 'Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('34.72'), Decimal('1.477469'), Decimal('10.5946')),
#  ('Western Asia', 'Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), Decimal('42.69'), Decimal('10.093121'), Decimal('10.5946')),
#  ('Western Asia', 'Armenia', 2020, Decimal('100.00'), Decimal('92.33'), Decimal('12.64'), Decimal('2.805608'), Decimal('10.5946'))]

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
