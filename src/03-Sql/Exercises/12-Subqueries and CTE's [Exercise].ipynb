# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Subqueries and CTEs
# © ExploreAI Academy

# %% [markdown]
# In this exercise, we will apply subqueries and CTEs in different parts of a query and for different use cases. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Know how to use CTEs to simplify subqueries.
# - Understand when to use subqueries and when to use CTEs by comparing their performance and readability.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///../db/Northwind.db

# %% [markdown]
# Here is a view of all of our tables in the database:

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:500px";/>
# <br>
# <br>
#     <em>Figure 1: Northwind ERD</em>
# </div>

# %% [markdown]
# ## Exercise
#
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Retrieve product details from products that have been ordered by customers from the UK.

# %%
# Add your code here

# %% [markdown]
# ### Exercise 2
#
#
# Find out the names of customers who have ordered products of more than the average order value.

# %%
# Add your code here

# %% [markdown]
# ### Exercise 3
#
#
# Write a CTE to find the most ordered product by each customer.

# %%
# Add your code here

# %% [markdown]
# ### Exercise 4
#
# Using a CTE, list employees who have more than the average number of reports.

# %%
# Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# SQL solution with a subquery:

# %%
# %%sql
#
# SELECT customers.*
# FROM customers
# WHERE customers.CustomerID IN (
#     SELECT orders.CustomerID
#     FROM orders
#     GROUP BY orders.CustomerID
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# );
# Out:
#  * sqlite:///../db/Northwind.db
# Done.
# [('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None)]

# %% [markdown]
# SQL solution with a CTE:

# %%
# %%sql
#
# WITH most_orders AS (
#     SELECT orders.CustomerID
#     FROM orders
#     GROUP BY orders.CustomerID
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# )
# SELECT customers.*
# FROM customers
# JOIN most_orders
# ON customers.CustomerID = most_orders.CustomerID;
# Out:
#  * sqlite:///../db/Northwind.db
# Done.
# [('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None)]

# %% [markdown]
# Both solutions will return the customer with the most orders. The subquery solution nests the logic inside the main query, which can become difficult to read for more complex queries. The CTE solution separates the logic into a different part of the query, which can be more readable, especially for more complex queries.

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# WITH avg_order_value AS (
#     SELECT AVG(OrderDetails.UnitPrice * OrderDetails.Quantity) AS average_value
#     FROM OrderDetails
# )
# SELECT DISTINCT customers.CompanyName
# FROM customers
# JOIN orders ON customers.CustomerID = orders.CustomerID
# JOIN OrderDetails ON orders.OrderID = OrderDetails.OrderID
# WHERE (OrderDetails.UnitPrice * OrderDetails.Quantity) > (SELECT average_value FROM avg_order_value);
# Out:
#  * sqlite:///../db/Northwind.db
# Done.
# [('Toms Spezialitten',),
#  ('Hanari Carnes',),
#  ('Suprmes dlices',),
#  ('Richter Supermarkt',),
#  ('HILARION-Abastos',),
#  ('Ernst Handel',),
#  ('Ottilies Kseladen',),
#  ('Blondesddsl pre et fils',),
#  ('Frankenversand',),
#  ('GROSELLA-Restaurante',),
#  ('Wartian Herkku',),
#  ('Rattlesnake Canyon Grocery',),
#  ('QUICK-Stop',),
#  ('Morgenstern Gesundkost',),
#  ('Berglunds snabbkp',),
#  ('LILA-Supermercado',),
#  ('Comrcio Mineiro',),
#  ('Tradio Hipermercados',),
#  ('Hungry Owl All-Night Grocers',),
#  ('Old World Delicatessen',),
#  ('Die Wandernde Kuh',),
#  ('Save-a-lot Markets',),
#  ('Kniglich Essen',),
#  ('Folk och f HB',),
#  ('Furia Bacalhau e Frutos do Mar',),
#  ('Split Rail Beer & Ale',),
#  ('Mre Paillarde',),
#  ("Bon app'",),
#  ('Lehmanns Marktstand',),
#  ('White Clover Markets',),
#  ('Familia Arquibaldo',),
#  ('Piccolo und mehr',),
#  ('Seven Seas Imports',),
#  ('Eastern Connection',),
#  ('Chop-suey Chinese',),
#  ('Queen Cozinha',),
#  ('Bottom-Dollar Markets',),
#  ('Princesa Isabel Vinhos',),
#  ('Magazzini Alimentari Riuniti',),
#  ('Folies gourmandes',),
#  ("La maison d'Asie",),
#  ('Simons bistro',),
#  ('Wellington Importadora',),
#  ('Que Delcia',),
#  ('Gourmet Lanchonetes',),
#  ('Victuailles en stock',),
#  ('Vaffeljernet',),
#  ("B's Beverages",),
#  ('Pericles Comidas clsicas',),
#  ('Ricardo Adocicados',),
#  ('LINO-Delicateses',),
#  ('Antonio Moreno Taquera',),
#  ('Tortuga Restaurante',),
#  ('Around the Horn',),
#  ('Great Lakes Food Market',),
#  ('The Cracker Box',),
#  ('Godos Cocina Tpica',),
#  ('Alfreds Futterkiste',),
#  ('Maison Dewey',),
#  ('Hungry Coyote Import Store',),
#  ('Lonesome Pine Restaurant',),
#  ("Let's Stop N Shop",),
#  ('Reggiani Caseifici',),
#  ('Blido Comidas preparadas',),
#  ('The Big Cheese',),
#  ('Drachenblut Delikatessen',),
#  ('Island Trading',),
#  ('Sant Gourmet',),
#  ('Consolidated Holdings',),
#  ('Spcialits du monde',),
#  ('France restauration',),
#  ('Ocano Atlntico Ltda.',),
#  ('Blauer See Delikatessen',)]

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# WITH most_ordered_products AS (
#     SELECT customers.CustomerID, OrderDetails.ProductID, COUNT(*) AS order_count
#     FROM customers
#     JOIN orders ON customers.CustomerID = orders.CustomerID
#     JOIN OrderDetails ON orders.OrderID = OrderDetails.OrderID
#     GROUP BY customers.CustomerID, OrderDetails.ProductID
# )
# SELECT customers.CompanyName, products.ProductName, max_order_count
# FROM (
#     SELECT CustomerID, MAX(order_count) AS max_order_count
#     FROM most_ordered_products
#     GROUP BY CustomerID
# ) AS max_order_count
# JOIN most_ordered_products ON max_order_count.CustomerID = most_ordered_products.CustomerID AND max_order_count.max_order_count = most_ordered_products.order_count
# JOIN customers ON most_ordered_products.CustomerID = customers.CustomerID
# JOIN products ON most_ordered_products.ProductID = products.ProductID;
# Out:
#  * sqlite:///../db/Northwind.db
# Done.
# [('Alfreds Futterkiste', 'Rssle Sauerkraut', 2),
#  ('Ana Trujillo Emparedados y helados', 'Queso Cabrales', 1),
#  ('Ana Trujillo Emparedados y helados', 'Konbu', 1),
#  ('Ana Trujillo Emparedados y helados', 'Tofu', 1),
#  ('Ana Trujillo Emparedados y helados', 'Teatime Chocolate Biscuits', 1),
#  ('Ana Trujillo Emparedados y helados', 'Mascarpone Fabioli', 1),
#  ('Ana Trujillo Emparedados y helados', 'Singaporean Hokkien Fried Mee', 1),
#  ('Ana Trujillo Emparedados y helados', 'Camembert Pierrot', 1),
#  ('Ana Trujillo Emparedados y helados', 'Gudbrandsdalsost', 1),
#  ('Ana Trujillo Emparedados y helados', 'Outback Lager', 1),
#  ('Ana Trujillo Emparedados y helados', 'Mozzarella di Giovanni', 1),
#  ('Antonio Moreno Taquera', 'Queso Cabrales', 2),
#  ('Antonio Moreno Taquera', 'Geitost', 2),
#  ('Around the Horn', 'Gorgonzola Telino', 3),
#  ('Berglunds snabbkp', 'Tourtire', 3),
#  ('Berglunds snabbkp', 'Rhnbru Klosterbier', 3),
#  ('Blauer See Delikatessen', "Sir Rodney's Scones", 3),
#  ('Blondesddsl pre et fils', 'Gorgonzola Telino', 2),
#  ('Blido Comidas preparadas', "Chef Anton's Cajun Seasoning", 1),
#  ('Blido Comidas preparadas', 'Alice Mutton', 1),
#  ('Blido Comidas preparadas', 'Thringer Rostbratwurst', 1),
#  ('Blido Comidas preparadas', 'Filo Mix', 1),
#  ('Blido Comidas preparadas', 'Ravioli Angelo', 1),
#  ('Blido Comidas preparadas', 'Rhnbru Klosterbier', 1),
#  ("Bon app'", 'Pavlova', 3),
#  ('Bottom-Dollar Markets', 'Tarte au sucre', 3),
#  ("B's Beverages", "Uncle Bob's Organic Dried Pears", 2),
#  ("B's Beverages", 'Konbu', 2),
#  ("B's Beverages", "Sir Rodney's Scones", 2),
#  ('Cactus Comidas para llevar', 'Rssle Sauerkraut', 1),
#  ('Cactus Comidas para llevar', 'Gorgonzola Telino', 1),
#  ('Cactus Comidas para llevar', 'Geitost', 1),
#  ('Cactus Comidas para llevar', 'Sasquatch Ale', 1),
#  ('Cactus Comidas para llevar', 'Steeleye Stout', 1),
#  ('Cactus Comidas para llevar', "Jack's New England Clam Chowder", 1),
#  ('Cactus Comidas para llevar', 'Ipoh Coffee', 1),
#  ('Cactus Comidas para llevar', 'Laughing Lumberjack Lager', 1),
#  ('Cactus Comidas para llevar', 'Scottish Longbreads', 1),
#  ('Cactus Comidas para llevar', 'Rd Kaviar', 1),
#  ('Cactus Comidas para llevar', 'Rhnbru Klosterbier', 1),
#  ('Centro comercial Moctezuma', "Sir Rodney's Scones", 1),
#  ('Centro comercial Moctezuma', 'Gravad lax', 1),
#  ('Chop-suey Chinese', 'Gnocchi di nonna Alice', 3),
#  ('Comrcio Mineiro', 'Spegesild', 2),
#  ('Consolidated Holdings', 'Chang', 1),
#  ('Consolidated Holdings', "Chef Anton's Gumbo Mix", 1),
#  ('Consolidated Holdings', 'Mishi Kobe Niku', 1),
#  ('Consolidated Holdings', 'Konbu', 1),
#  ('Consolidated Holdings', "Gustaf's Knckebrd", 1),
#  ('Consolidated Holdings', 'Tunnbrd', 1),
#  ('Consolidated Holdings', 'Mozzarella di Giovanni', 1),
#  ('Drachenblut Delikatessen', 'Konbu', 2),
#  ('Du monde entier', 'Chai', 1),
#  ('Du monde entier', 'Ikura', 1),
#  ('Du monde entier', 'Alice Mutton', 1),
#  ('Du monde entier', "Sir Rodney's Scones", 1),
#  ('Du monde entier', 'Sasquatch Ale', 1),
#  ('Du monde entier', "Jack's New England Clam Chowder", 1),
#  ('Du monde entier', 'Singaporean Hokkien Fried Mee', 1),
#  ('Du monde entier', 'Filo Mix', 1),
#  ('Du monde entier', 'Gudbrandsdalsost', 1),
#  ('Eastern Connection', "Uncle Bob's Organic Dried Pears", 2),
#  ('Eastern Connection', 'Flotemysost', 2),
#  ('Ernst Handel', 'Alice Mutton', 4),
#  ('Ernst Handel', 'Guaran Fantstica', 4),
#  ('Ernst Handel', 'Gorgonzola Telino', 4),
#  ('Ernst Handel', 'Wimmers gute Semmelkndel', 4),
#  ('Familia Arquibaldo', 'Guaran Fantstica', 2),
#  ('Familia Arquibaldo', 'Rhnbru Klosterbier', 2),
#  ('Folies gourmandes', 'Carnarvon Tigers', 2),
#  ('Folk och f HB', 'Chang', 3),
#  ('Folk och f HB', "Jack's New England Clam Chowder", 3),
#  ('Folk och f HB', 'Manjimup Dried Apples', 3),
#  ('Folk och f HB', 'Rhnbru Klosterbier', 3),
#  ('Frankenversand', "Sir Rodney's Scones", 3),
#  ('Frankenversand', 'Tunnbrd', 3),
#  ('France restauration', 'Pavlova', 1),
#  ('France restauration', 'Thringer Rostbratwurst', 1),
#  ('France restauration', 'Manjimup Dried Apples', 1),
#  ('France restauration', 'Tarte au sucre', 1),
#  ('France restauration', 'Louisiana Fiery Hot Pepper Sauce', 1),
#  ('France restauration', 'Lakkalikri', 1),
#  ('Franchi S.p.A.', 'Carnarvon Tigers', 1),
#  ('Franchi S.p.A.', 'Teatime Chocolate Biscuits', 1),
#  ('Franchi S.p.A.', 'Gumbr Gummibrchen', 1),
#  ('Franchi S.p.A.', 'Boston Crab Meat', 1),
#  ('Franchi S.p.A.', 'Rogede sild', 1),
#  ('Franchi S.p.A.', 'Zaanse koeken', 1),
#  ('Franchi S.p.A.', 'Manjimup Dried Apples', 1),
#  ('Franchi S.p.A.', 'Camembert Pierrot', 1),
#  ('Franchi S.p.A.', 'Longlife Tofu', 1),
#  ('Franchi S.p.A.', 'Original Frankfurter grne Soe', 1),
#  ('Furia Bacalhau e Frutos do Mar', 'Gula Malacca', 2),
#  ('Furia Bacalhau e Frutos do Mar', 'Gnocchi di nonna Alice', 2),
#  ('Furia Bacalhau e Frutos do Mar', 'Camembert Pierrot', 2),
#  ('Furia Bacalhau e Frutos do Mar', 'Louisiana Fiery Hot Pepper Sauce', 2),
#  ('Galera del gastrnomo', 'Ikura', 1),
#  ('Galera del gastrnomo', 'NuNuCa Nu-Nougat-Creme', 1),
#  ('Galera del gastrnomo', 'Zaanse koeken', 1),
#  ('Galera del gastrnomo', 'Gnocchi di nonna Alice', 1),
#  ('Galera del gastrnomo', 'Wimmers gute Semmelkndel', 1),
#  ('Galera del gastrnomo', 'Louisiana Fiery Hot Pepper Sauce', 1),
#  ('Galera del gastrnomo', 'Lakkalikri', 1),
#  ('Galera del gastrnomo', 'Original Frankfurter grne Soe', 1),
#  ('Godos Cocina Tpica', 'Alice Mutton', 2),
#  ('Godos Cocina Tpica', 'Pt chinois', 2),
#  ('Godos Cocina Tpica', 'Wimmers gute Semmelkndel', 2),
#  ('Godos Cocina Tpica', 'Louisiana Fiery Hot Pepper Sauce', 2),
#  ('Godos Cocina Tpica', 'Scottish Longbreads', 2),
#  ('Gourmet Lanchonetes', 'Nord-Ost Matjeshering', 2),
#  ('Gourmet Lanchonetes', 'Singaporean Hokkien Fried Mee', 2),
#  ('Great Lakes Food Market', "Sir Rodney's Scones", 2),
#  ('Great Lakes Food Market', 'Cte de Blaye', 2),
#  ('GROSELLA-Restaurante', 'Ikura', 1),
#  ('GROSELLA-Restaurante', 'Thringer Rostbratwurst', 1),
#  ('GROSELLA-Restaurante', 'Mozzarella di Giovanni', 1),
#  ('GROSELLA-Restaurante', 'Rhnbru Klosterbier', 1),
#  ('Hanari Carnes', 'Gorgonzola Telino', 3),
#  ('Hanari Carnes', 'Cte de Blaye', 3),
#  ('Hanari Carnes', 'Louisiana Fiery Hot Pepper Sauce', 3),
#  ('HILARION-Abastos', 'Guaran Fantstica', 3),
#  ('HILARION-Abastos', 'Gudbrandsdalsost', 3),
#  ('HILARION-Abastos', 'Rhnbru Klosterbier', 3),
#  ('Hungry Coyote Import Store', 'Tourtire', 2),
#  ('Hungry Owl All-Night Grocers', 'Flotemysost', 4),
#  ('Island Trading', 'Tunnbrd', 2),
#  ('Island Trading', 'Outback Lager', 2),
#  ('Island Trading', 'Flotemysost', 2),
#  ('Island Trading', 'Lakkalikri', 2),
#  ('Kniglich Essen', 'Raclette Courdavault', 3),
#  ("La corne d'abondance", "Uncle Bob's Organic Dried Pears", 1),
#  ("La corne d'abondance", 'Alice Mutton', 1),
#  ("La corne d'abondance", "Sir Rodney's Marmalade", 1),
#  ("La corne d'abondance", 'Gumbr Gummibrchen', 1),
#  ("La corne d'abondance", 'Schoggi Schokolade', 1),
#  ("La corne d'abondance", 'Geitost', 1),
#  ("La corne d'abondance", "Jack's New England Clam Chowder", 1),
#  ("La corne d'abondance", 'Filo Mix', 1),
#  ("La corne d'abondance", 'Outback Lager', 1),
#  ("La corne d'abondance", 'Rhnbru Klosterbier', 1),
#  ("La corne d'abondance", 'Lakkalikri', 1),
#  ("La maison d'Asie", 'Inlagd Sill', 3),
#  ('Laughing Bacchus Wine Cellars', 'Konbu', 1),
#  ('Laughing Bacchus Wine Cellars', 'Tunnbrd', 1),
#  ('Laughing Bacchus Wine Cellars', 'Guaran Fantstica', 1),
#  ('Laughing Bacchus Wine Cellars', 'NuNuCa Nu-Nougat-Creme', 1),
#  ('Laughing Bacchus Wine Cellars', "Jack's New England Clam Chowder", 1),
#  ('Laughing Bacchus Wine Cellars', 'Filo Mix', 1),
#  ('Laughing Bacchus Wine Cellars', 'Outback Lager', 1),
#  ('Laughing Bacchus Wine Cellars', 'Original Frankfurter grne Soe', 1),
#  ('Lazy K Kountry Store', 'Queso Cabrales', 1),
#  ('Lazy K Kountry Store', 'Boston Crab Meat', 1),
#  ('Lehmanns Marktstand', 'Nord-Ost Matjeshering', 3),
#  ("Let's Stop N Shop", 'Genen Shouyu', 1),
#  ("Let's Stop N Shop", 'Carnarvon Tigers', 1),
#  ("Let's Stop N Shop", "Sir Rodney's Scones", 1),
#  ("Let's Stop N Shop", 'Nord-Ost Matjeshering', 1),
#  ("Let's Stop N Shop", 'Tourtire', 1),
#  ("Let's Stop N Shop", 'Gnocchi di nonna Alice', 1),
#  ("Let's Stop N Shop", "Sirop d'rable", 1),
#  ("Let's Stop N Shop", 'Louisiana Fiery Hot Pepper Sauce', 1),
#  ("Let's Stop N Shop", 'Rhnbru Klosterbier', 1),
#  ("Let's Stop N Shop", 'Original Frankfurter grne Soe', 1),
#  ('LILA-Supermercado', 'Queso Cabrales', 2),
#  ('LILA-Supermercado', 'Gumbr Gummibrchen', 2),
#  ('LILA-Supermercado', 'Nord-Ost Matjeshering', 2),
#  ('LILA-Supermercado', 'Camembert Pierrot', 2),
#  ('LILA-Supermercado', 'Mozzarella di Giovanni', 2),
#  ('LILA-Supermercado', 'Original Frankfurter grne Soe', 2),
#  ('LINO-Delicateses', 'Chai', 2),
#  ('LINO-Delicateses', 'Aniseed Syrup', 2),
#  ('LINO-Delicateses', 'Pavlova', 2),
#  ('LINO-Delicateses', 'Teatime Chocolate Biscuits', 2),
#  ('LINO-Delicateses', 'NuNuCa Nu-Nougat-Creme', 2),
#  ('LINO-Delicateses', 'Steeleye Stout', 2),
#  ('LINO-Delicateses', 'Boston Crab Meat', 2),
#  ('LINO-Delicateses', 'Rogede sild', 2),
#  ('LINO-Delicateses', 'Outback Lager', 2),
#  ('Lonesome Pine Restaurant', 'Scottish Longbreads', 2),
#  ('Magazzini Alimentari Riuniti', "Chef Anton's Cajun Seasoning", 2),
#  ('Magazzini Alimentari Riuniti', 'Guaran Fantstica', 2),
#  ('Maison Dewey', 'Northwoods Cranberry Sauce', 1),
#  ('Maison Dewey', "Sir Rodney's Scones", 1),
#  ('Maison Dewey', 'NuNuCa Nu-Nougat-Creme', 1),
#  ('Maison Dewey', 'Gumbr Gummibrchen', 1),
#  ('Maison Dewey', 'Schoggi Schokolade', 1),
#  ('Maison Dewey', 'Rssle Sauerkraut', 1),
#  ('Maison Dewey', 'Boston Crab Meat', 1),
#  ('Maison Dewey', 'Ipoh Coffee', 1),
#  ('Maison Dewey', 'Gula Malacca', 1),
#  ('Maison Dewey', 'Rogede sild', 1),
#  ('Maison Dewey', 'Pt chinois', 1),
#  ('Maison Dewey', 'Gnocchi di nonna Alice', 1),
#  ('Maison Dewey', 'Raclette Courdavault', 1),
#  ('Maison Dewey', 'Scottish Longbreads', 1),
#  ('Maison Dewey', 'Gudbrandsdalsost', 1),
#  ('Maison Dewey', 'Mozzarella di Giovanni', 1),
#  ('Maison Dewey', 'Lakkalikri', 1),
#  ('Mre Paillarde', 'Pavlova', 2),
#  ('Mre Paillarde', 'Gnocchi di nonna Alice', 2),
#  ('Mre Paillarde', 'Tarte au sucre', 2),
#  ('Mre Paillarde', 'Wimmers gute Semmelkndel', 2),
#  ('Mre Paillarde', 'Scottish Longbreads', 2),
#  ('Morgenstern Gesundkost', 'Tarte au sucre', 2),
#  ('North/South', 'Outback Lager', 2),
#  ('Ocano Atlntico Ltda.', "Chef Anton's Gumbo Mix", 1),
#  ('Ocano Atlntico Ltda.', "Uncle Bob's Organic Dried Pears", 1),
#  ('Ocano Atlntico Ltda.', 'Queso Cabrales', 1),
#  ('Ocano Atlntico Ltda.', 'Konbu', 1),
#  ('Ocano Atlntico Ltda.', 'Tofu', 1),
#  ('Ocano Atlntico Ltda.', "Sir Rodney's Marmalade", 1),
#  ('Ocano Atlntico Ltda.', "Sir Rodney's Scones", 1),
#  ('Ocano Atlntico Ltda.', 'Raclette Courdavault', 1),
#  ('Ocano Atlntico Ltda.', 'Mozzarella di Giovanni', 1),
#  ('Ocano Atlntico Ltda.', 'Lakkalikri', 1),
#  ('Ocano Atlntico Ltda.', 'Original Frankfurter grne Soe', 1),
#  ('Old World Delicatessen', 'Pavlova', 3),
#  ('Ottilies Kseladen', "Jack's New England Clam Chowder", 3),
#  ('Pericles Comidas clsicas', 'Chai', 1),
#  ('Pericles Comidas clsicas', 'Queso Cabrales', 1),
#  ('Pericles Comidas clsicas', 'Tofu', 1),
#  ('Pericles Comidas clsicas', 'Guaran Fantstica', 1),
#  ('Pericles Comidas clsicas', 'Rssle Sauerkraut', 1),
#  ('Pericles Comidas clsicas', 'Thringer Rostbratwurst', 1),
#  ('Pericles Comidas clsicas', 'Boston Crab Meat', 1),
#  ('Pericles Comidas clsicas', 'Rogede sild', 1),
#  ('Pericles Comidas clsicas', 'Manjimup Dried Apples', 1),
#  ('Pericles Comidas clsicas', 'Filo Mix', 1),
#  ('Pericles Comidas clsicas', 'Perth Pasties', 1),
#  ('Pericles Comidas clsicas', 'Camembert Pierrot', 1),
#  ('Pericles Comidas clsicas', 'Laughing Lumberjack Lager', 1),
#  ('Pericles Comidas clsicas', 'Rhnbru Klosterbier', 1),
#  ('Piccolo und mehr', 'Queso Cabrales', 2),
#  ('Piccolo und mehr', 'Alice Mutton', 2),
#  ('Piccolo und mehr', 'Gudbrandsdalsost', 2),
#  ('Princesa Isabel Vinhos', "Sir Rodney's Scones", 2),
#  ('Que Delcia', 'Steeleye Stout', 3),
#  ('Queen Cozinha', 'Boston Crab Meat', 3),
#  ('QUICK-Stop', 'Singaporean Hokkien Fried Mee', 4),
#  ('QUICK-Stop', 'Camembert Pierrot', 4),
#  ('Rancho grande', 'Pavlova', 1),
#  ('Rancho grande', "Sir Rodney's Marmalade", 1),
#  ('Rancho grande', "Sir Rodney's Scones", 1),
#  ('Rancho grande', 'Gumbr Gummibrchen', 1),
#  ('Rancho grande', 'Mascarpone Fabioli', 1),
#  ('Rancho grande', 'Cte de Blaye', 1),
#  ('Rancho grande', 'Boston Crab Meat', 1),
#  ('Rancho grande', 'Spegesild', 1),
#  ('Rancho grande', 'Maxilaku', 1),
#  ('Rancho grande', 'Manjimup Dried Apples', 1),
#  ('Rancho grande', 'Ravioli Angelo', 1),
#  ('Rancho grande', "Sirop d'rable", 1),
#  ('Rattlesnake Canyon Grocery', 'Alice Mutton', 4),
#  ('Rattlesnake Canyon Grocery', 'Gnocchi di nonna Alice', 4),
#  ('Rattlesnake Canyon Grocery', 'Tarte au sucre', 4),
#  ('Reggiani Caseifici', "Uncle Bob's Organic Dried Pears", 2),
#  ('Reggiani Caseifici', 'Filo Mix', 2),
#  ('Ricardo Adocicados', 'Chang', 3),
#  ('Richter Supermarkt', 'Chang', 2),
#  ('Richter Supermarkt', 'Gumbr Gummibrchen', 2),
#  ('Richter Supermarkt', 'Gudbrandsdalsost', 2),
#  ('Richter Supermarkt', 'Rd Kaviar', 2),
#  ('Romero y tomillo', 'Nord-Ost Matjeshering', 3),
#  ('Sant Gourmet', 'Guaran Fantstica', 2),
#  ('Save-a-lot Markets', 'Chang', 5),
#  ('Seven Seas Imports', 'Queso Cabrales', 2),
#  ('Seven Seas Imports', 'Rssle Sauerkraut', 2),
#  ('Seven Seas Imports', 'Manjimup Dried Apples', 2),
#  ('Simons bistro', 'Pavlova', 1),
#  ('Simons bistro', "Sir Rodney's Scones", 1),
#  ('Simons bistro', 'Nord-Ost Matjeshering', 1),
#  ('Simons bistro', 'Geitost', 1),
#  ('Simons bistro', 'Inlagd Sill', 1),
#  ('Simons bistro', 'Cte de Blaye', 1),
#  ('Simons bistro', 'Spegesild', 1),
#  ('Simons bistro', 'Manjimup Dried Apples', 1),
#  ('Simons bistro', 'Pt chinois', 1),
#  ('Simons bistro', 'Raclette Courdavault', 1),
#  ('Simons bistro', "Sirop d'rable", 1),
#  ('Simons bistro', 'Tarte au sucre', 1),
#  ('Simons bistro', 'Scottish Longbreads', 1),
#  ('Simons bistro', 'Mozzarella di Giovanni', 1),
#  ('Simons bistro', 'Original Frankfurter grne Soe', 1),
#  ('Spcialits du monde', 'Queso Cabrales', 1),
#  ('Spcialits du monde', 'Pavlova', 1),
#  ('Spcialits du monde', 'Carnarvon Tigers', 1),
#  ('Spcialits du monde', 'Cte de Blaye', 1),
#  ('Spcialits du monde', 'Gudbrandsdalsost', 1),
#  ('Spcialits du monde', 'Rhnbru Klosterbier', 1),
#  ('Split Rail Beer & Ale', 'Tourtire', 2),
#  ('Split Rail Beer & Ale', 'Gnocchi di nonna Alice', 2),
#  ('Split Rail Beer & Ale', 'Scottish Longbreads', 2),
#  ('Suprmes dlices', 'Singaporean Hokkien Fried Mee', 3),
#  ('The Big Cheese', "Chef Anton's Gumbo Mix", 1),
#  ('The Big Cheese', 'Pavlova', 1),
#  ('The Big Cheese', 'Sasquatch Ale', 1),
#  ('The Big Cheese', 'Inlagd Sill', 1),
#  ('The Big Cheese', 'Cte de Blaye', 1),
#  ('The Big Cheese', 'Tarte au sucre', 1),
#  ('The Big Cheese', 'Mozzarella di Giovanni', 1),
#  ('The Cracker Box', 'Chai', 1),
#  ('The Cracker Box', 'Ikura', 1),
#  ('The Cracker Box', 'Rssle Sauerkraut', 1),
#  ('The Cracker Box', 'Thringer Rostbratwurst', 1),
#  ('The Cracker Box', 'Boston Crab Meat', 1),
#  ('The Cracker Box', 'Gula Malacca', 1),
#  ('The Cracker Box', 'Filo Mix', 1),
#  ('The Cracker Box', 'Laughing Lumberjack Lager', 1),
#  ('Toms Spezialitten', 'Teatime Chocolate Biscuits', 3),
#  ('Tortuga Restaurante', 'Gula Malacca', 3),
#  ('Tradio Hipermercados', "Chef Anton's Cajun Seasoning", 1),
#  ('Tradio Hipermercados', "Grandma's Boysenberry Spread", 1),
#  ('Tradio Hipermercados', "Sir Rodney's Marmalade", 1),
#  ('Tradio Hipermercados', 'Thringer Rostbratwurst', 1),
#  ('Tradio Hipermercados', 'Nord-Ost Matjeshering', 1),
#  ('Tradio Hipermercados', 'Gorgonzola Telino', 1),
#  ('Tradio Hipermercados', 'Chartreuse verte', 1),
#  ('Tradio Hipermercados', 'Pt chinois', 1),
#  ('Tradio Hipermercados', 'Escargots de Bourgogne', 1),
#  ('Tradio Hipermercados', 'Camembert Pierrot', 1),
#  ('Tradio Hipermercados', 'Tarte au sucre', 1),
#  ('Tradio Hipermercados', 'Scottish Longbreads', 1),
#  ('Tradio Hipermercados', 'Mozzarella di Giovanni', 1),
#  ("Trail's Head Gourmet Provisioners", 'Tarte au sucre', 2),
#  ('Vaffeljernet', 'Original Frankfurter grne Soe', 4),
#  ('Victuailles en stock', "Uncle Bob's Organic Dried Pears", 2),
#  ('Victuailles en stock', 'Ikura', 2),
#  ('Victuailles en stock', 'Louisiana Fiery Hot Pepper Sauce', 2),
#  ('Vins et alcools Chevalier', 'Mozzarella di Giovanni', 2),
#  ('Die Wandernde Kuh', 'Gorgonzola Telino', 2),
#  ('Die Wandernde Kuh', 'Mascarpone Fabioli', 2),
#  ('Die Wandernde Kuh', 'Pt chinois', 2),
#  ('Die Wandernde Kuh', 'Gudbrandsdalsost', 2),
#  ('Wartian Herkku', 'Tofu', 3),
#  ('Wartian Herkku', 'Perth Pasties', 3),
#  ('Wartian Herkku', 'Flotemysost', 3),
#  ('Wellington Importadora', 'Chai', 2),
#  ('Wellington Importadora', 'Carnarvon Tigers', 2),
#  ('Wellington Importadora', 'Outback Lager', 2),
#  ('White Clover Markets', 'Chang', 2),
#  ('White Clover Markets', 'Pavlova', 2),
#  ('White Clover Markets', 'Alice Mutton', 2),
#  ('White Clover Markets', "Sir Rodney's Scones", 2),
#  ('White Clover Markets', 'Geitost', 2),
#  ('White Clover Markets', 'Sasquatch Ale', 2),
#  ('White Clover Markets', 'Gnocchi di nonna Alice', 2),
#  ('White Clover Markets', 'Tarte au sucre', 2),
#  ('Wilman Kala', 'Chai', 1),
#  ('Wilman Kala', 'Northwoods Cranberry Sauce', 1),
#  ('Wilman Kala', 'Queso Manchego La Pastora', 1),
#  ('Wilman Kala', 'Pavlova', 1),
#  ('Wilman Kala', 'Teatime Chocolate Biscuits', 1),
#  ('Wilman Kala', "Sir Rodney's Scones", 1),
#  ('Wilman Kala', 'Guaran Fantstica', 1),
#  ('Wilman Kala', 'Rssle Sauerkraut', 1),
#  ('Wilman Kala', 'Boston Crab Meat', 1),
#  ('Wilman Kala', 'Singaporean Hokkien Fried Mee', 1),
#  ('Wilman Kala', 'Ipoh Coffee', 1),
#  ('Wilman Kala', 'Maxilaku', 1),
#  ('Wilman Kala', 'Pt chinois', 1),
#  ('Wilman Kala', 'Raclette Courdavault', 1),
#  ('Wilman Kala', "Sirop d'rable", 1),
#  ('Wilman Kala', 'Louisiana Fiery Hot Pepper Sauce', 1),
#  ('Wilman Kala', 'Lakkalikri', 1),
#  ('Wolski  Zajazd', 'Chang', 2),
#  ('Wolski  Zajazd', "Sirop d'rable", 2)]

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# WITH avg_reports AS (
#     SELECT AVG(report_count) AS average_count
#     FROM (
#         SELECT COUNT(*) AS report_count
#         FROM employees
#         JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
#         GROUP BY employees.EmployeeID
#     ) AS report_counts
# )
# SELECT employees.*
# FROM employees
# JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
# GROUP BY employees.EmployeeID
# HAVING COUNT(*) > (SELECT average_count FROM avg_reports);
# Out:
#  * sqlite:///../db/Northwind.db
# Done.
# [(2, 'Fuller', 'Andrew', 'Vice President, Sales', 'Dr.', '1952-02-19 00:00:00', '1992-08-14 00:00:00', '908 W. Capital Way', 'Tacoma', 'WA', '98401', 'USA', '(206) 555-9482', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and  ... (150 characters truncated) ... es in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', None, 'http://accweb/emmployees/fuller.bmp', 2254.49)]

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
