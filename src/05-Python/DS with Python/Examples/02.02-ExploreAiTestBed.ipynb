# %%
import pandas as pd

# %%
# Create list of lists containing data.
list_df = [[32, 'Portugal', 94], [30, 'Argentina', 93], [25 , 'Brazil', 92]]

# Create index – names of players.
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# Create column names.
columns = ['Age', 'Nationality', 'Overall']

# Create a DataFrame by passing in data, index, and columns.
pd.DataFrame(data=list_df, index=index, columns=columns)
# Out:
#                     Age Nationality  Overall
# Christiano Ronaldo   32    Portugal       94
# Lionel Messi         30   Argentina       93
# Neymar               25      Brazil       92

# %%
# Create dictionary containing data.
dict_df = {'Age':[32, 30, 25], 'Nationality':['Portugal', 'Argentina', 'Brazil'], 'Overall':[94, 93, 92]}

# Create index – names of players.
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# Create a DataFrame by passing in data, index, and columns.
pd.DataFrame(data=dict_df, index=index)
# Out:
#                     Age Nationality  Overall
# Christiano Ronaldo   32    Portugal       94
# Lionel Messi         30   Argentina       93
# Neymar               25      Brazil       92

# %%
# Load data – pass 'Name' as our index column.
# For this exercise, we'll use football player data to evaluate our DataFrame.
load_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv', index_col ='Name')

# Create a DataFrame called df.
df = pd.DataFrame(load_df)

# Use the head() function to look at the first 5 rows.
df.head()
# Out:
# <ipython-input-7-f3ec09cd7bd5>:3: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   load_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv', index_col ='Name')
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# ...

# %%
# Select the 5th row using iloc[].
df.iloc[4]
# Out:
# Age                         31
# Nationality            Germany
# Overall                     92
# Acceleration            58
# Aggression              29
# Agility                 52
# Balance                 35
# Ball control            48
# Composure               70
# Crossing                15
# Curve                   14
# Dribbling               30
# Finishing               13
# Free kick accuracy      11
# GK diving               91
# GK handling             90
# GK kicking              95
# GK positioning          91
# GK reflexes             89
# Heading accuracy        25
# Interceptions           30
# Jumping                 78
# Long passing            59
# Long shots              16
# Marking                 10
# Penalties               47
# Positioning             12
# Reactions               85
# Short passing           55
# Shot power              25
# Sliding tackle          11
# Sprint speed            61
# Stamina                 44
# Standing tackle         10
# ...

# %%
# Select rows 5 to 10.
df.iloc[4:10]
# Out:
#                 Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# M. Neuer         31     Germany       92       58         29      52
# R. Lewandowski   28      Poland       91       79         80      78
# De Gea           26       Spain       90       57         38      60
# E. Hazard        26     Belgium       90       93         54      93
# T. Kroos         27     Germany       90       60         60      71
# G. Higuaín       29   Argentina       90       78         50      75
#
#                Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                    ...
# M. Neuer        35           48        70       15      ...        55
# R. Lewandowski  80           89        87       62      ...        83
# De Gea          43           42        64       17      ...        50
# E. Hazard       91           92        87       80      ...        86
# ...

# %%
# Select the M. Neuer index using loc[].
df.loc['M. Neuer']
# Out:
# Age                         31
# Nationality            Germany
# Overall                     92
# Acceleration            58
# Aggression              29
# Agility                 52
# Balance                 35
# Ball control            48
# Composure               70
# Crossing                15
# Curve                   14
# Dribbling               30
# Finishing               13
# Free kick accuracy      11
# GK diving               91
# GK handling             90
# GK kicking              95
# GK positioning          91
# GK reflexes             89
# Heading accuracy        25
# Interceptions           30
# Jumping                 78
# Long passing            59
# Long shots              16
# Marking                 10
# Penalties               47
# Positioning             12
# Reactions               85
# Short passing           55
# Shot power              25
# Sliding tackle          11
# Sprint speed            61
# Stamina                 44
# Standing tackle         10
# ...

# %%
# Select the column 'Age'.
df['Age']
# Out:
# Name
# Cristiano Ronaldo    32
# L. Messi             30
# Neymar               25
# L. Suárez            30
# M. Neuer             31
#                      ..
# A. Kelsey            17
# B. Richardson        47
# J. Young             17
# J. Lundstram         18
# L. Sackey            18
# Name: Age, Length: 17981, dtype: int64

# %%
# Select the columns 'Age' and 'Nationality'.
df[['Age', 'Nationality']]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany
# ...                ...         ...
# A. Kelsey           17     England
# B. Richardson       47     England
# J. Young            17    Scotland
# J. Lundstram        18     England
# L. Sackey           18       Ghana
#
# [17981 rows x 2 columns]

# %%
# Select the first 5 rows and first 2 columns – Rows first.
df.iloc[0:5][['Age', 'Nationality']]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
# Select the first 5 rows and first 2 columns – Columns first.
df[['Age', 'Nationality']].iloc[0:5]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
import pandas as pd
import numpy as np

# %%
dict_df = {
    "Crop": ['Wheat', 'Corn', 'Rice', 'Soybean'],
    "Yields per Acre (in tons)": [3, 4.5, 5, 2.8],
    "Country": ['USA', 'China', 'India', 'Brazil']
}
pd.DataFrame(data=dict_df)[1:3]
# Out:
#    Crop  Yields per Acre (in tons) Country
# 1  Corn                        4.5   China
# 2  Rice                        5.0   India

# %%
data=np.array([[30, 25], [60, 30], [25, 20]])
columns = ['Max_Height_m', 'Growth_Rate_cm_per_year']
index = ['Maple', 'Pine', 'Birch']
pd.DataFrame(data=data,index=index,columns=columns).loc['Maple']
# Out:
# Max_Height_m               30
# Growth_Rate_cm_per_year    25
# Name: Maple, dtype: int64

# %%
animal_data = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/Python/Animals.csv')
animal_df = pd.DataFrame(animal_data)
animal_df[animal_df['Conservation Status'] == 'Critically Endangered']
# Out:
#      Species  Average Lifespan (Years)      Habitat    Conservation Status
# 9  Orangutan                        35  Rainforests  Critically Endangered

# %%
# Load data - pass 'Name' as our index column.
df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv', index_col='Nationality')

# Use the head() function to look at the first 5 rows.
df.head()
# Out:
# <ipython-input-18-32ab4a29889e>:2: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv', index_col='Nationality')
#                           Name  Age  Overall Acceleration Aggression Agility  \
# Nationality
# Portugal     Cristiano Ronaldo   32       94       89         63      89
# Argentina             L. Messi   30       93       92         48      90
# Brazil                  Neymar   25       92       94         56      96
# Uruguay              L. Suárez   30       92       88         78      86
# Germany               M. Neuer   31       92       58         29      52
#
#             Balance Ball control Composure Crossing  ... Short passing  \
# Nationality                                          ...
# Portugal     63           93        95       85      ...        83
# ...

# %%
# Sort by age from oldest to youngest (select first 5 entries).
df.sort_values(by='Age', ascending=False).head()
# Out:
#                       Name  Age  Overall Acceleration Aggression Agility  \
# Nationality
# England      B. Richardson   47       46       25         44      35
# Egypt         E. El Hadary   44       70       28         29      21
# Mexico            O. Pérez   44       71       60         26      69
# England          J. Walker   43       55       22         41      53
# Wales             D. Coyne   43       55       36         36      48
#
#             Balance Ball control Composure Crossing  ... Short passing  \
# Nationality                                          ...
# England      44           22        44       11      ...        12
# Egypt        41           25        57       20      ...        16
# Mexico       69           23        50       19      ...        26
# England      64           38        35       16      ...        22
# Wales        58           31        57       13      ...        28
#
# ...

# %%
# Filter on players older than 30 and overall rating greater than 90.
df[(df['Age'] > 30) & (df['Overall'] > 90)]
# Out:
#                           Name  Age  Overall Acceleration Aggression Agility  \
# Nationality
# Portugal     Cristiano Ronaldo   32       94       89         63      89
# Germany               M. Neuer   31       92       58         29      52
#
#             Balance Ball control Composure Crossing  ... Short passing  \
# Nationality                                          ...
# Portugal     63           93        95       85      ...        83
# Germany      35           48        70       15      ...        55
#
#             Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Nationality
# Portugal        94             23           91      92              31
# Germany         25             11           61      44              10
#
#             Strength  Vision Volleys Preferred Positions
# Nationality
# Portugal      80      85      88                  ST LW
# Germany       83      70      11                     GK
#
# [2 rows x 38 columns]

# %%
# Create a column of rating per year of age.
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at the first 5 entries.
df['Rating Per Year of Age'].head(9)
# Out:
# Nationality
# Portugal     2.937500
# Argentina    3.100000
# Brazil       3.680000
# Uruguay      3.066667
# Germany      2.967742
# Poland       3.250000
# Spain        3.461538
# Belgium      3.461538
# Germany      3.333333
# Name: Rating Per Year of Age, dtype: float64

# %%
# Drop the column we just created in Example 5
df = df.drop('Rating Per Year of Age', axis=1)

df.head(7)
# Out:
#                           Name  Age  Overall Acceleration Aggression Agility  \
# Nationality
# Portugal     Cristiano Ronaldo   32       94       89         63      89
# Argentina             L. Messi   30       93       92         48      90
# Brazil                  Neymar   25       92       94         56      96
# Uruguay              L. Suárez   30       92       88         78      86
# Germany               M. Neuer   31       92       58         29      52
# Poland          R. Lewandowski   28       91       79         80      78
# Spain                   De Gea   26       90       57         38      60
#
#             Balance Ball control Composure Crossing  ... Short passing  \
# Nationality                                          ...
# Portugal     63           93        95       85      ...        83
# Argentina    95           95        96       77      ...        88
# Brazil       82           95        92       75      ...        81
# ...

# %%
# Let's look at the average rating by age (first 5 rows).
df.groupby('Age')[['Overall']].mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %%
# Look at the average rating by age and nationality (first 15 rows).
df.groupby(['Age', 'Nationality'])[['Overall']].mean().head(15)
# Out:
#                    Overall
# Age Nationality
# 16  Argentina    56.000000
#     England      61.500000
#     France       54.000000
#     Germany      57.000000
#     Italy        61.000000
#     Netherlands  62.000000
#     Norway       54.500000
#     Romania      54.000000
#     Spain        58.000000
# 17  Algeria      54.000000
#     Argentina    57.333333
#     Australia    52.000000
#     Austria      54.500000
#     Belgium      58.250000
#     Canada       56.000000

# %%
# Change the age column to months and look at the first 5 entries.
df['Age'].apply(lambda age: age * 12).head()
# Out:
# Nationality
# Portugal     384
# Argentina    360
# Brazil       300
# Uruguay      360
# Germany      372
# Name: Age, dtype: int64

# %%
# Create function.
def position_type(s):

    """"This function converts the individual positions (abbreviations) and classifies it
    as either a Forward, Midfielder, Back, or Goalkeeper"""

    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# %%
# Create position type column.
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# Look at the first 5 entries.
df['Preferred Positions Type'].head()
# Out:
# Nationality
# Portugal        Forward
# Argentina       Forward
# Brazil          Forward
# Uruguay         Forward
# Germany      GoalKeeper
# Name: Preferred Positions Type, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Portugal to Ghana
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17981 non-null  object
#  1   Age                       17981 non-null  int64
#  2   Overall                   17981 non-null  int64
#  3   Acceleration              17981 non-null  object
#  4   Aggression                17981 non-null  object
#  5   Agility                   17981 non-null  object
#  6   Balance                   17981 non-null  object
#  7   Ball control              17981 non-null  object
#  8   Composure                 17981 non-null  object
#  9   Crossing                  17981 non-null  object
#  10  Curve                     17981 non-null  object
#  11  Dribbling                 17981 non-null  object
#  12  Finishing                 17981 non-null  object
# ...

# %%
# Select all numeric attribute columns, i.e. excluding "word-type" columns such as Nationality.
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
# Create function.
def to_float(x):
    "Transforms numeric attribute columns to type float"

    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

# %%
# Use the map() function to transform all selected columns.
df[cols] = df[cols].map(to_float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-3d3959ad7512> in <cell line: 2>()
#       1 # Use the map() function to transform all selected columns.
# ----> 2 df[cols] = df[cols].map(to_float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
df[cols] = np.vectorize(to_float)(df[cols])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Portugal to Ghana
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17981 non-null  object
#  1   Age                       17981 non-null  int64
#  2   Overall                   17981 non-null  float64
#  3   Acceleration              17981 non-null  float64
#  4   Aggression                17981 non-null  float64
#  5   Agility                   17981 non-null  float64
#  6   Balance                   17981 non-null  float64
#  7   Ball control              17981 non-null  float64
#  8   Composure                 17981 non-null  float64
#  9   Crossing                  17981 non-null  float64
#  10  Curve                     17981 non-null  float64
#  11  Dribbling                 17981 non-null  float64
#  12  Finishing                 17981 non-null  float64
# ...

# %%
animal_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/Python/Animals.csv')

# %%
Mean_lifespan_by_habitat = animal_df.groupby('Habitat')['Average Lifespan (Years)'].mean().sort_values(ascending=False)
Mean_lifespan_by_habitat
# Out:
# Habitat
# Ocean                 80.0
# Oceans, Beaches       80.0
# Grasslands            60.0
# Rainforests           35.0
# Islands               30.0
# Arctic                25.0
# Antarctic             20.0
# Forests, Seacoasts    20.0
# Temperate Forest      20.0
# Forests               15.0
# Mountain Ranges       15.0
# Savanna               14.0
# Eucalyptus Forests    13.0
# Forests, Tundra        8.0
# Various                5.0
# Name: Average Lifespan (Years), dtype: float64
