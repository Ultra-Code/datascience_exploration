# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MD_agric_exam-4313.csv')

# %%
df
# Out:
#      Field_ID  Elevation  Rainfall  Min_temperature_C  Max_temperature_C  \
# 0        1162  494.95615    1507.6               -5.4               31.0
# 1        5108  663.73390     581.0               -4.7               30.9
# 2        3504  396.87990    1715.1               -6.1               31.7
# 3        5351  594.80370    1748.0               -4.3               33.6
# 4         905  609.49800    1395.8               -4.5               31.3
# ..        ...        ...       ...                ...                ...
# 995      2202  572.95935     625.6               -5.5               31.0
# 996      2531  552.80945     398.1               -5.9               33.4
# 997      1040  678.22504     564.4               -4.6               31.7
# 998        58  792.65370     928.5               -3.3               31.2
# 999      3334  747.69850     981.5               -3.7               31.0
#
#            pH  Pollution_level  Plot_size  Annual_yield Crop_type
# 0    6.859436         0.007034        3.6      1.617421    coffee
# 1    5.603219         0.289643        4.2      2.532497    potato
# 2    5.774116         0.000409        2.6      1.262207    banana
# 3    6.477415         0.088777        7.9      4.351564     wheat
# 4    5.419586         0.050023       10.8      5.034791   cassava
# ..        ...              ...        ...           ...       ...
# 995  5.258964         0.086330        1.2      0.750675     wheat
# 996  4.607136         0.130178        0.8      0.449790     wheat
# 997  5.567556         0.448149        1.2      0.492988     maize
# 998  5.102048         0.387350        1.1      0.597557    potato
# 999  6.715882         0.541706       11.1      2.867815    coffee
#
# [1000 rows x 10 columns]

# %%
df["Crop_type"].unique()
# Out:
# array(['coffee', 'potato', 'banana', 'wheat', 'cassava', 'maize', 'tea',
#        'rice'], dtype=object)

# %%
df[df["Crop_type"] == "wheat"].max()
# Out:
# Field_ID                  5632
# Elevation            1003.9437
# Rainfall                2009.6
# Min_temperature_C         -1.4
# Max_temperature_C         35.7
# pH                    7.482802
# Pollution_level       0.930238
# Plot_size                 14.9
# Annual_yield          8.994376
# Crop_type                wheat
# dtype: object

# %%
df[df["Pollution_level"] > 0.2]["Rainfall"].sum()
# Out:
# 478902.6

# %%
def temperature_range(field):
    fields = df[df["Field_ID"] == field]
    return fields["Max_temperature_C"] - fields["Min_temperature_C"]

for field_id in [1458, 1895, 5443]:
    print(temperature_range(field_id))
# Out:
# 135    40.7
# dtype: float64
# 644    35.7
# dtype: float64
# 892    33.4
# dtype: float64

# %%
data = df
a = data['Crop_type'].unique()
b = float('inf')
c = ''

for crop in a:
    d = data[data['Crop_type'] == crop]['Min_temperature_C'].mean()
    if d < b:
        b = d
        c = crop

print(c)
# Out:
# rice

# %%
df[df["pH"] < 5.5]["Plot_size"].sum()
# Out:
# 1731.8999999999999

# %%
df[(df['Min_temperature_C'] < -5) & (df['Max_temperature_C'] > 30)]
# Out:
#      Field_ID  Elevation  Rainfall  Min_temperature_C  Max_temperature_C  \
# 0        1162  494.95615    1507.6               -5.4               31.0
# 2        3504  396.87990    1715.1               -6.1               31.7
# 5        2274  270.45100    1665.2               -7.2               34.3
# 13       4807  520.29770     292.3               -6.3               32.9
# 14        973  432.03570    1464.4               -6.0               30.2
# ..        ...        ...       ...                ...                ...
# 990      1637  504.66306    1144.5               -5.7               32.1
# 991       756  578.91270     889.4               -5.2               31.0
# 992      1332  359.76013    1816.0               -6.4               32.9
# 995      2202  572.95935     625.6               -5.5               31.0
# 996      2531  552.80945     398.1               -5.9               33.4
#
#            pH  Pollution_level  Plot_size  Annual_yield Crop_type
# 0    6.859436         0.007034        3.6      1.617421    coffee
# 2    5.774116         0.000409        2.6      1.262207    banana
# 5    5.873082         0.001545        3.9      1.743458    banana
# 13   5.379286         0.196589        1.4      0.881568    potato
# 14   7.482802         0.019800        3.0      1.377434     wheat
# ..        ...              ...        ...           ...       ...
# 990  5.666609         0.431891        4.8      2.486276     wheat
# 991  5.062155         0.442495        2.2      1.209928   cassava
# 992  7.350705         0.133453        2.9      1.225715     wheat
# 995  5.258964         0.086330        1.2      0.750675     wheat
# 996  4.607136         0.130178        0.8      0.449790     wheat
#
# [319 rows x 10 columns]

# %%
df.describe()
# Out:
#           Field_ID    Elevation     Rainfall  Min_temperature_C  \
# count  1000.000000  1000.000000  1000.000000        1000.000000
# mean   2779.486000   628.136035  1197.734700          -4.504100
# std    1595.068372   179.098546   497.794699           1.568117
# min       1.000000    35.910797   110.100000          -9.700000
# 25%    1442.250000   504.392825   771.575000          -5.600000
# 50%    2728.500000   657.468975  1194.900000          -4.400000
# 75%    4133.000000   761.075752  1616.900000          -3.300000
# max    5632.000000  1003.943700  2408.500000          -1.200000
#
#        Max_temperature_C           pH  Pollution_level    Plot_size  \
# count         1000.00000  1000.000000     1.000000e+03  1000.000000
# mean            30.89460     5.603899     2.233740e-01     3.962400
# std              1.92225     0.802154     2.288665e-01     3.459036
# min             25.10000     3.701838     5.397448e-10     0.500000
# 25%             29.57500     5.018775     4.449419e-02     1.500000
# 50%             30.90000     5.562078     1.661962e-01     2.900000
# 75%             32.20000     6.201437     3.077840e-01     4.700000
# max             37.30000     7.484683     9.954134e-01    15.000000
#
#        Annual_yield
# count   1000.000000
# mean       2.101536
# std        1.926694
# min        0.174857
# 25%        0.786612
# 50%        1.478622
# 75%        2.519811
# max       12.695224

# %%
#df["Rainfall"]
np.std(df[(df['Plot_size'] > df["Plot_size"].median())]["Rainfall"])
# Out:
# 469.6199685856172

# %%
df.mode()["Max_temperature_C"]
# Out:
# 0      30.7
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 995     NaN
# 996     NaN
# 997     NaN
# 998     NaN
# 999     NaN
# Name: Max_temperature_C, Length: 1000, dtype: float64

# %%
df.groupby('Crop_type').size()
# Out:
# Crop_type
# banana     103
# cassava    141
# coffee      99
# maize       82
# potato     146
# rice        48
# tea        137
# wheat      244
# dtype: int64

# %%
# @title Crop_type

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Crop_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.corr(numeric_only=True)
# Out:
#                    Field_ID  Elevation  Rainfall  Min_temperature_C  \
# Field_ID           1.000000   0.010592 -0.002144           0.008935
# Elevation          0.010592   1.000000 -0.268527           0.958888
# Rainfall          -0.002144  -0.268527  1.000000           0.012915
# Min_temperature_C  0.008935   0.958888  0.012915           1.000000
# Max_temperature_C -0.012077  -0.633348  0.199348          -0.598835
# pH                -0.005710  -0.424522  0.028025          -0.431778
# Pollution_level    0.073132   0.277520 -0.190407           0.231964
# Plot_size          0.017024   0.005116  0.100076           0.034513
# Annual_yield       0.006469   0.043852  0.095577           0.073219
#
#                    Max_temperature_C        pH  Pollution_level  Plot_size  \
# Field_ID                   -0.012077 -0.005710         0.073132   0.017024
# Elevation                  -0.633348 -0.424522         0.277520   0.005116
# Rainfall                    0.199348  0.028025        -0.190407   0.100076
# Min_temperature_C          -0.598835 -0.431778         0.231964   0.034513
# Max_temperature_C           1.000000  0.282096        -0.183352   0.018223
# pH                          0.282096  1.000000        -0.113847   0.050053
# Pollution_level            -0.183352 -0.113847         1.000000  -0.020970
# Plot_size                   0.018223  0.050053        -0.020970   1.000000
# Annual_yield               -0.020977  0.008961        -0.076525   0.948398
#
#                    Annual_yield
# Field_ID               0.006469
# Elevation              0.043852
# Rainfall               0.095577
# Min_temperature_C      0.073219
# Max_temperature_C     -0.020977
# pH                     0.008961
# Pollution_level       -0.076525
# Plot_size              0.948398
# Annual_yield           1.000000

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/ultracode/.cache/pypoetry/virtualenvs/datascience-Hp-DJPih-py3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Categorize the 'Elevation' into three ranges: Low, Medium, High
df['Elevation_Category'] = pd.cut(df['Elevation'],
                                  bins=[-float('inf'), 300, 600, float('inf')],
                                  labels=['Low', 'Medium', 'High'])

# Create a violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Elevation_Category', y='Annual_yield', data=df)

# Set plot labels and title
plt.xlabel('Elevation Category')
plt.ylabel('Annual Yield')
plt.title('Violin Plot of Annual Yield Across Elevation Ranges')

# Show the plot
plt.show()

# %%
uniq = df["Crop_type"].unique()
crop_len =lambda crop: len(crop)
sum = 0
for crop in uniq:
    sum+=crop_len(crop)

print(sum)
# Out:
# 42

# %%
#Write Python code to perform a t-test comparing the average 'Annual_yield' between 'coffee' and 'banana' crop types using scipy.stats. 
# What is the p-value, rounded to three decimal places?
from scipy import stats

coffee = df[df['Crop_type'] == 'coffee']['Annual_yield']
banana = df[df['Crop_type'] == 'banana']['Annual_yield']
# Example for independent samples t-test:
t_statistic, p_value = stats.ttest_ind(coffee,banana)

print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# T-statistic: -0.5277
# P-value: 0.5983

# %%
avg_cal = df.groupby("Crop_type")['Rainfall'].mean()
print(avg_cal)
# Out:
# Crop_type
# banana     1714.556311
# cassava    1267.440426
# coffee     1503.530303
# maize       697.365854
# potato      642.878082
# rice       1649.493750
# tea        1537.594891
# wheat      1035.681967
# Name: Rainfall, dtype: float64

# %%
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde as gkde

data = {'Group A': [2, 5, 7, 4, 8], 'Group B': [3, 6, 9, 5, 10]}
df = pd.DataFrame(data)

# Kernel density estimation for each group
kde_a = gkde(df['Group A'])
kde_b = gkde(df['Group B'])

# Generate x-axis values
x = np.linspace(df['Group A'].min(), df['Group B'].max(), 100)

# Calculate KDE values
density_a = kde_a(x)
density_b = kde_b(x)

# Plot the KDEs
plt.plot(x, density_a, label='Group A')
plt.plot(x, density_b, label='Group B')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Distribution of Group A vs. Group B (KDE)')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create boxplots
plt.figure(figsize=(8, 6))
plt.boxplot(df[['Group A', 'Group B']], labels=['Group A', 'Group B'])

# Add labels and title
plt.xlabel('Group')
plt.ylabel('Value')
plt.title('Distribution of Group A vs. Group B (Boxplots)')

# Show the plot
plt.show()
